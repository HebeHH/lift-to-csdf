# %%
import re
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

import numpy as np

# %% [markdown]
# # Success Rate

# %%
labels = 'Could not generate CSDF',  'Success'
sizes = [2,27]
explode = 0,1


ff = {'family':'serif',
      'sans-serif':['Adobe Arabic'],
      'serif':['Times'],
      'size': 14
     }


plt.rc('font', **ff)

fig1, ax1 = plt.subplots(figsize=(5,5))
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',  startangle=90)
ax1.axis('equal') 

plt.title("CSDF Generation Success Rate", pad=20, 
          fontdict={'family':'sans-serif', 'size':18})
plt.savefig("Graphs/GenerationSuccessRatePie.png")

# %%
with open("ufrecord.txt") as f:
    firstver = f.readlines()

# %%
results = {"file" : [firstver[i] for i in range(0, len(firstver), 5)],
"thruput" : [float(re.findall(r'[0-9].+', firstver[i])[0]) for i in range(2, len(firstver), 5)],
"period" : [float(re.findall(r'[0-9].+', firstver[i])[0]) for i in range(3, len(firstver), 5)]}
results = pd.DataFrame(results)
results.thruput = pd.to_numeric(results.thruput)
results.period = pd.to_numeric(results.period)
results['name'] = [re.findall(r'/([a-zA-Z]+)', x)[0] for x in results.file]

# %%
results = results[[True if '[' not  in x else False for x in results.file ]]

results['par'] = ['_par' in x for x in results.file]
results['rec'] = ['_rec' in x for x in results.file]
results['dz'] = ['_dz' in x for x in results.file]
results['cmap'] = ['_cmap_' in x for x in results.file]
results['svs'] = [int(re.findall(r'[0-9]+', x)[0]) for x in results.file]

# %%
df = results[results.name == "mydot"]
df = df[~df.par]
ls = ['par', 'svs']
res = (df).merge(df, on = ls)
res['diffe'] = res.period_x/res.period_y
smsm = np.logical_and(res.dz_x == res.dz_y, res.cmap_x == res.cmap_y)
erk = np.logical_and(res.dz_x == False,  False == res.dz_y)
dz2 = np.logical_and(res.dz_x == True,  False == res.dz_y)
cmap2 = np.logical_and(res.cmap_x == False,  True == res.cmap_y)
the2s = np.logical_or(cmap2, dz2)
notrel = np.logical_or(smsm, erk)
notrel = np.logical_or(notrel, the2s)
ltd = ['period_x', "period_y", 'par', 'svs', 'dz_x', 'dz_y', 'cmap_x', 'cmap_y', 'diffe']

res[~notrel][ltd].head(40)
# Out:
#       period_x   period_y    par  svs   dz_x  dz_y  cmap_x  cmap_y     diffe
# 2     411900.0   413300.0  False  100  False  True   False   False  0.996613
# 6     411900.0   413300.0  False  100  False  True    True   False  0.996613
# 7     411900.0   402000.0  False  100  False  True    True    True  1.024627
# 14    402000.0   413300.0  False  100   True  True    True   False  0.972659
# 18      4290.0     4430.0  False   10  False  True   False   False  0.968397
# 22      4290.0     4430.0  False   10  False  True    True   False  0.968397
# 23      4290.0     4200.0  False   10  False  True    True    True  1.021429
# 30      4200.0     4430.0  False   10   True  True    True   False  0.948081
# 34    592680.0   594360.0  False  120  False  True   False   False  0.997173
# 38    592680.0   594360.0  False  120  False  True    True   False  0.997173
# 39    592680.0   578400.0  False  120  False  True    True    True  1.024689
# 46    578400.0   594360.0  False  120   True  True    True   False  0.973148
# 50    925350.0   927450.0  False  150  False  True   False   False  0.997736
# 54    925350.0   927450.0  False  150  False  True    True   False  0.997736
# 55    925350.0   903000.0  False  150  False  True    True    True  1.024751
# 62    903000.0   927450.0  False  150   True  True    True   False  0.973637
# 66   1643800.0  1646600.0  False  200  False  True   False   False  0.998300
# 70   1643800.0  1646600.0  False  200  False  True    True   False  0.998300
# 71   1643800.0  1604000.0  False  200  False  True    True    True  1.024813
# 78   1604000.0  1646600.0  False  200   True  True    True   False  0.974129
# 82   2567250.0  2570750.0  False  250  False  True   False   False  0.998639
# 86   2567250.0  2570750.0  False  250  False  True    True   False  0.998639
# 87   2567250.0  2505000.0  False  250  False  True    True    True  1.024850
# 94   2505000.0  2570750.0  False  250   True  True    True   False  0.974424
# 98   3695700.0  3699900.0  False  300  False  True   False   False  0.998865
# 102  3695700.0  3699900.0  False  300  False  True    True   False  0.998865
# 103  3695700.0  3606000.0  False  300  False  True    True    True  1.024875
# 110  3606000.0  3699900.0  False  300   True  True    True   False  0.974621
# 114    37470.0    37890.0  False   30  False  True   False   False  0.988915
# 118    37470.0    37890.0  False   30  False  True    True   False  0.988915
# 119    37470.0    36600.0  False   30  False  True    True    True  1.023770
# 126    36600.0    37890.0  False   30   True  True    True   False  0.965954
# 130  5029150.0  5034050.0  False  350  False  True   False   False  0.999027
# 134  5029150.0  5034050.0  False  350  False  True    True   False  0.999027
# 135  5029150.0  4907000.0  False  350  False  True    True    True  1.024893
# 142  4907000.0  5034050.0  False  350   True  True    True   False  0.974762
# 146  6567600.0  6573200.0  False  400  False  True   False   False  0.999148
# 150  6567600.0  6573200.0  False  400  False  True    True   False  0.999148
# 151  6567600.0  6408000.0  False  400  False  True    True    True  1.024906
# 158  6408000.0  6573200.0  False  400   True  True    True   False  0.974868

# %% [markdown]
# If not composing maps, then should use arrayed zip (1-10% benefit, depending on size) because dearraying the zip will introduce some overhead with no chance of recovery.
#
# If !cmap then !dz (bigger effect at smaller number)
# If cmap then dz (bigger effect at bigger number)
# If dz then cmap
# If !dz then no difference

# %%
results['ufs'] = [int(re.findall(r'[0-9]+', x)[1]) for x in results.file]
results.sort_values('svs')
# Out:
#                            file       thruput       period name    par    rec  \
# 386     curr/uf_3_10_par_.xml\n  3.333333e-02         30.0   uf   True  False
# 387     curr/uf_3_10_rec_.xml\n  3.703704e-03        270.0   uf  False   True
# 385    curr/uf_3_100_rec_.xml\n  9.259259e-04       1080.0   uf  False   True
# 407     curr/uf_3_80_rec_.xml\n  1.111111e-03        900.0   uf  False   True
# 406     curr/uf_3_80_par_.xml\n  4.166667e-03        240.0   uf   True  False
# ..                          ...           ...          ...  ...    ...    ...
# 547  curr/uf_500_500_rec_.xml\n  7.692308e-09  130000000.0   uf  False   True
# 548   curr/uf_500_50_par_.xml\n  4.000000e-06     250000.0   uf   True  False
# 549   curr/uf_500_50_rec_.xml\n  5.714286e-08   17500000.0   uf  False   True
# 528  curr/uf_500_100_par_.xml\n  4.000000e-06     250000.0   uf   True  False
# 551   curr/uf_500_80_rec_.xml\n  4.000000e-08   25000000.0   uf  False   True
#
#         dz   cmap  svs  ufs
# 386  False  False    3   10
# 387  False  False    3   10
# 385  False  False    3  100
# 407  False  False    3   80
# 406  False  False    3   80
# ..     ...    ...  ...  ...
# 547  False  False  500  500
# 548  False  False  500   50
# 549  False  False  500   50
# 528  False  False  500  100
# 551  False  False  500   80
#
# [720 rows x 10 columns]

# %%
# results[~results.cmap]

# res = recres.merge(parres, left_on=['name'], right_on=['name'],
#           suffixes=('_recursive', '_parallel'))

def merge(var, df):
    ls = ['name', 'svs','ufs']
    res = (df[df[var]]).merge(df[~df[var]], on = ls,
          suffixes=('_'+var, '_not'+var))
    res['diffe'] = res['period_'+var] / res['period_not'+var]
    plt.hist(res.diffe, bins = 60)
    plt.plot()
    return res

k = merge('par', results)
# k[k.diffe == k.diffe.min()]
# [x for x in c if x != 1]
# k.groupby(['cmap']).diffe.min()
# k.sort_values(['svs'])

# %%
colors =[ 'red', 'blue', 'green', 'indigo', 'yellow', 'orange', 'black',  'purple', 'violet', 'red', 'blue', 'green', 'indigo', 'yellow', 'orange', 'black',  'purple', 'violet','lime']
for i in k.ufs.unique():
    j=k[k.ufs==i].sort_values('diffe')
    plt.plot(j.diffe, j.svs, color=colors.pop())
plt.plot()
# Out:
# []

# %%
k.groupby('ufs').diffe.max()-k.groupby('ufs').diffe.min()
# Out:
# ufs
# 3      0.101449
# 10     0.077778
# 20     0.141667
# 50     0.223810
# 80     0.256667
# 100    0.269444
# 150    0.288235
# 200    0.298485
# 250    0.304938
# 300    0.309375
# 450    0.317021
# 500    0.318590
# Name: diffe, dtype: float64

# %%
# results[~results.cmap]

# res = recres.merge(parres, left_on=['name'], right_on=['name'],
#           suffixes=('_recursive', '_parallel'))

def merge(var, df):
    ls = ['name', 'par', 'svs', 'cmap', 'dz']
    ls.remove(var)
    res = (df[df[var]]).merge(df[~df[var]], on = ls,
          suffixes=('_'+var, '_not'+var))
    res['diffe'] = res['period_'+var] / res['period_not'+var]
    plt.hist(res.diffe, bins = 60)
    plt.plot()
    return res

k = merge('par', results[results.name == 'mydotsmol'])
# k[k.diffe == k.diffe.min()]
# [x for x in c if x != 1]
# k.groupby(['cmap']).diffe.min()
# k.sort_values(['svs'])

# %%
fig, ax = plt.subplots(figsize=(5,5))
# j = k[np.logical_and(k.dz == False, k.cmap == False)]
ax.scatter(j.svs, j.diffe)
# ax.legend()
# plt.plot()
plt.show()

# %%
df = results[results.name == 'mydot']
df = df[df.rec]
ls = ['name', 'par', 'svs']
var = np.logical_and(df.dz == False, df.cmap == False)

k = (df[var]).merge(df[~var], on = ls,
      suffixes=('_ff', '_notff'))
k['diffe'] =  k['period_notff'] / k['period_ff'] 
# plt.hist(k.diffe, bins = 60)
# plt.plot()

# %%
fig, ax = plt.subplots(figsize=(5,5))

# True, True
ax.scatter(k[np.logical_and(k.dz_notff == True, k.cmap_notff == True)].diffe, 
            k[np.logical_and(k.dz_notff == True, k.cmap_notff == True)].svs, color='red', label='both')
# False, True
ax.scatter(k[np.logical_and(k.dz_notff == False, k.cmap_notff == True)].diffe, 
            k[np.logical_and(k.dz_notff == False, k.cmap_notff == True)].svs, color='blue', label='cm')

# True, False
ax.scatter(k[np.logical_and(k.dz_notff == True, k.cmap_notff == False)].diffe, 
            k[np.logical_and(k.dz_notff == True, k.cmap_notff == False)].svs, color='green', label='dz')

ax.legend()
# plt.plot()
plt.show()

# %%
j = results[results.name == 'addlisttoarray']
j = j[j.svs == 50]
j
# Out:
#                                          file       thruput     period  \
# 52           curr/addlisttoarray_par50_.xml\n  8.000000e-06   125000.0
# 53      curr/addlisttoarray_par50_cmap_.xml\n  8.000000e-06   125000.0
# 54        curr/addlisttoarray_par50_dz_.xml\n  8.000000e-06   125000.0
# 55   curr/addlisttoarray_par50_dz_cmap_.xml\n  8.000000e-06   125000.0
# 112          curr/addlisttoarray_rec50_.xml\n  4.705882e-07  2125000.0
# 113     curr/addlisttoarray_rec50_cmap_.xml\n  4.705882e-07  2125000.0
# 114       curr/addlisttoarray_rec50_dz_.xml\n  4.705882e-07  2125000.0
# 115  curr/addlisttoarray_rec50_dz_cmap_.xml\n  4.705882e-07  2125000.0
#
#                name    par    rec     dz   cmap  svs
# 52   addlisttoarray   True  False  False  False   50
# 53   addlisttoarray   True  False  False   True   50
# 54   addlisttoarray   True  False   True  False   50
# 55   addlisttoarray   True  False   True   True   50
# 112  addlisttoarray  False   True  False  False   50
# 113  addlisttoarray  False   True  False   True   50
# 114  addlisttoarray  False   True   True  False   50
# 115  addlisttoarray  False   True   True   True   50

# %%
plt.scatter(k[np.logical_and(k.dz == True, k.cmap == False)].diffe, 
            k[np.logical_and(k.dz == True, k.cmap == False)].svs, color='green')

# %%
parres = results[['_par' in x for x in results.file]]
recres = results[['_notpar' in x for x in results.file]]

# %%
parres
# Out:
#                                     file   thruput   period  name   par  \
# 0              mystuff/asum_par50_.xml\n  0.001000   1000.0  asum  True
# 1         mystuff/asum_par50_cmap_.xml\n  0.001000   1000.0  asum  True
# 2          mystuff/asum_par[1000]_.xml\n  0.000050  20000.0  asum  True
# 3     mystuff/asum_par[1000]_cmap_.xml\n  0.000050  20000.0  asum  True
# 4            mystuff/asum_par[10]_.xml\n  0.005000    200.0  asum  True
# ...                                  ...       ...      ...   ...   ...
# 1395    mystuff/scal_par[80]_cmap_.xml\n  0.000625   1600.0  scal  True
# 1396        mystuff/scal_par[900]_.xml\n  0.000056  18000.0  scal  True
# 1397   mystuff/scal_par[900]_cmap_.xml\n  0.000056  18000.0  scal  True
# 1398         mystuff/scal_par[90]_.xml\n  0.000556   1800.0  scal  True
# 1399    mystuff/scal_par[90]_cmap_.xml\n  0.000556   1800.0  scal  True
#
#         rec   cmap      svs
# 0     False  False    (50,)
# 1     False   True    (50,)
# 2     False  False  (1000,)
# 3     False   True  (1000,)
# 4     False  False    (10,)
# ...     ...    ...      ...
# 1395  False   True    (80,)
# 1396  False  False   (900,)
# 1397  False   True   (900,)
# 1398  False  False    (90,)
# 1399  False   True    (90,)
#
# [720 rows x 8 columns]

# %%
res = recres.merge(parres, on=['name', 'svs'],
          suffixes=('_recursive', '_parallel'))
res
# Out:
#                          file_recursive  thruput_recursive  period_recursive  \
# 0             mystuff/asum_rec50_.xml\n           0.001000            1000.0
# 1             mystuff/asum_rec50_.xml\n           0.001000            1000.0
# 2        mystuff/asum_rec50_cmap_.xml\n           0.001000            1000.0
# 3        mystuff/asum_rec50_cmap_.xml\n           0.001000            1000.0
# 4         mystuff/asum_rec[1000]_.xml\n           0.000050           20000.0
# ...                                 ...                ...               ...
# 1435  mystuff/scal_rec[900]_cmap_.xml\n           0.000056           18000.0
# 1436        mystuff/scal_rec[90]_.xml\n           0.000556            1800.0
# 1437        mystuff/scal_rec[90]_.xml\n           0.000556            1800.0
# 1438   mystuff/scal_rec[90]_cmap_.xml\n           0.000556            1800.0
# 1439   mystuff/scal_rec[90]_cmap_.xml\n           0.000556            1800.0
#
#       name  par_recursive  rec_recursive  cmap_recursive      svs  \
# 0     asum          False           True           False    (50,)
# 1     asum          False           True           False    (50,)
# 2     asum          False           True            True    (50,)
# 3     asum          False           True            True    (50,)
# 4     asum          False           True           False  (1000,)
# ...    ...            ...            ...             ...      ...
# 1435  scal          False           True            True   (900,)
# 1436  scal          False           True           False    (90,)
# 1437  scal          False           True           False    (90,)
# 1438  scal          False           True            True    (90,)
# 1439  scal          False           True            True    (90,)
#
#                           file_parallel  thruput_parallel  period_parallel  \
# 0             mystuff/asum_par50_.xml\n          0.001000           1000.0
# 1        mystuff/asum_par50_cmap_.xml\n          0.001000           1000.0
# 2             mystuff/asum_par50_.xml\n          0.001000           1000.0
# 3        mystuff/asum_par50_cmap_.xml\n          0.001000           1000.0
# 4         mystuff/asum_par[1000]_.xml\n          0.000050          20000.0
# ...                                 ...               ...              ...
# 1435  mystuff/scal_par[900]_cmap_.xml\n          0.000056          18000.0
# 1436        mystuff/scal_par[90]_.xml\n          0.000556           1800.0
# 1437   mystuff/scal_par[90]_cmap_.xml\n          0.000556           1800.0
# 1438        mystuff/scal_par[90]_.xml\n          0.000556           1800.0
# 1439   mystuff/scal_par[90]_cmap_.xml\n          0.000556           1800.0
#
#       par_parallel  rec_parallel  cmap_parallel
# 0             True         False          False
# 1             True         False           True
# 2             True         False          False
# 3             True         False           True
# 4             True         False          False
# ...            ...           ...            ...
# 1435          True         False           True
# 1436          True         False          False
# 1437          True         False           True
# 1438          True         False          False
# 1439          True         False           True
#
# [1440 rows x 14 columns]

# %%
res = recres.merge(parres, left_on='name', right_on='name',
          suffixes=('_recursive', '_parallel'))
def prettify_df(k):
    return k[['name'] + [c for c in k.columns if 'thruput' in c] + [c for c in k.columns if 'period' in c] ]

res = prettify_df(res)
res.
# Out:
#                 name  thruput_recursive  thruput_parallel  period_recursive  \
# 0               asum       1.666667e-03      1.666667e-03             600.0
# 1       blackScholes       6.666667e-04      6.666667e-04            1500.0
# 2                dot       2.222222e-05      2.150538e-05           45000.0
# 3              gemvN       1.424501e-06      1.734305e-06          702000.0
# 4              gemvT       1.424501e-06      1.734305e-06          702000.0
# 5          gesummvNN       2.000000e-02      2.000000e-02              50.0
# 6          gesummvTT       3.333333e-03      3.333333e-03             300.0
# 7         mandelbrot       2.222222e-05      2.222222e-05           45000.0
# 8               mmNN       4.748338e-08      5.781015e-08        21060000.0
# 9               mmNT       4.748338e-08      5.781015e-08        21060000.0
# 10              mmTN       4.748338e-08      5.781015e-08        21060000.0
# 11              mmTT       4.748338e-08      5.781015e-08        21060000.0
# 12      mriqComputeQ       6.613757e-07      7.168459e-07         1512000.0
# 13        mriqPhiMag       6.666667e-04      6.666667e-04            1500.0
# 14                mv       1.424501e-06      1.734305e-06          702000.0
# 15            mvAsMM       1.424501e-06      1.734305e-06          702000.0
# 16  nearestNeighbour       6.666667e-04      6.666667e-04            1500.0
# 17              scal       1.666667e-03      1.666667e-03             600.0
#
#     period_parallel
# 0             600.0
# 1            1500.0
# 2           46500.0
# 3          576600.0
# 4          576600.0
# 5              50.0
# 6             300.0
# 7           45000.0
# 8        17298000.0
# 9        17298000.0
# 10       17298000.0
# 11       17298000.0
# 12        1395000.0
# 13           1500.0
# 14         576600.0
# 15         576600.0
# 16           1500.0
# 17            600.0
