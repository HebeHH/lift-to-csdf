# %%
# %run Generators.ipynb

from os import listdir
from os.path import isfile, join
from tqdm import tqdm
# Out:
# n1: Param
# n2: Param
# n3: Param
# n4: Param
# n10XDA_x0: Dearray
# n10XDA_x1: Dearray
# n10XRA: Rearray
# n10XZippee: Zippee
# n9XDA: Dearray
# n9XRA: Rearray
# n9XJnr: Joiner
# n9XSpl: Splitter
# n5_x1: Param
# n7_x1: Get
# n8_x1: Get
# n6_x1: Mather
# n5_x2: Param
# n7_x2: Get
# n8_x2: Get
# n6_x2: Mather
# n5_x3: Param
# n7_x3: Get
# n8_x3: Get
# n6_x3: Mather
# n11XDA: Dearray
# n11XRA: Rearray
# n11XPARA: Param
# [('n1', 'n11XDA', 'Array (3, Array (3, Float))')]
# [('n11XPARA', 'n4', 'Array (3, Float)')]
# [('n11XDA', 'n3', 'Array (3, Float)')]
# [('n9XRA', 'n11XPARA', 'Array (3, Float)')]
# [('n11XPARA', 'n11XRA', 'Array (3, Float)')]
# [('n3', 'n10XDA_x0', 'Array (3, Float)')]
# [('n4', 'n10XDA_x1', 'Array (3, Float)')]
# [('n10XRA', 'n9XDA', 'Array (3, Tuple (Float, Float))')]
# [('n10XDA_x0', 'n10XZippee', 'Float')]
# [('n10XDA_x1', 'n10XZippee', 'Float')]
# [('n10XZippee', 'n10XRA', 'Tuple (Float, Float)')]
# [('n9XDA', 'n9XSpl', 'Tuple (Float, Float)')]
# [('n9XJnr', 'n9XRA', 'Float')]
# [('n9XSpl', 'n5_x1', 'Tuple (Float, Float)')]
# [('n6_x1', 'n9XJnr', 'Float')]
# [('n5_x1', 'n7_x1', 'Tuple (Float, Float)')]
# [('n7_x1', 'n6_x1', 'Float')]
# [('n5_x1', 'n8_x1', 'Tuple (Float, Float)')]
# [('n8_x1', 'n6_x1', 'Float')]
# [('n9XSpl', 'n5_x2', 'Tuple (Float, Float)')]
# [('n6_x2', 'n9XJnr', 'Float')]
# [('n5_x2', 'n7_x2', 'Tuple (Float, Float)')]
# [('n7_x2', 'n6_x2', 'Float')]
# [('n5_x2', 'n8_x2', 'Tuple (Float, Float)')]
# [('n8_x2', 'n6_x2', 'Float')]
# [('n9XSpl', 'n5_x3', 'Tuple (Float, Float)')]
# [('n6_x3', 'n9XJnr', 'Float')]
# [('n5_x3', 'n7_x3', 'Tuple (Float, Float)')]
# [('n7_x3', 'n6_x3', 'Float')]
# [('n5_x3', 'n8_x3', 'Tuple (Float, Float)')]
# [('n8_x3', 'n6_x3', 'Float')]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/Dropbox/Uni/Capstone/lift-to-csdf/Generators.ipynb in <module>
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
fs = """asum                           gemvN                                   mmTT                         
 blackScholes                   gemvT                          mandelbrot                     molecularDynamics              mv                             scal
  gesummvNN                             mvAsMM   addlisttoarray
 dot                            gesummvTT                      mmNN              mappy             mriqComputeQ                   nbody
               mmNT              gesummvttfull        gesummvnnfull
                 kmeans                         mmTN      mydotsmol  mydot                     mriqPhiMag                     nearestNeighbour"""
fs = [x.strip() for x in fs.split(' ') if len(x) > 1]
fs

# %%
mypath = 'highlevel/'
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f)) and not f.endswith('json')]

# %%
len(onlyfiles)

# %%
recmethods = [discrete_zip, parallel_map, recursive_reduce]
printgraph_simple(compose_maps( try_do("highLevel/mydot", recmethods, [3] * 10)['graph']))

# %%
k = compose_maps( try_do("highLevel/addlisttoarray", recmethods, [3] * 10)['graph'])
# write_csdf(k, 'csdf_xmls/mdtpar.xml')

# %%
len(fs)

# %%
csdfs = []
names = []

# %%
# try_do("highLevel/mydot", parmethods, [sv] * 10)
mypath = 'highlevel/'
fs = [f for f in listdir(mypath) if isfile(join(mypath, f)) and not f.endswith('json')]
fs = [x for x in fs if 'mm' not in x] + ['mmNT']
fs = ['mmNT']
# csdfs = []
# done: [3, 5, 7, 10, 15, 50]
parreducemethods = [parallel_reduce, recursive_map, recursive_reduce]
parmethods = [parallel_reduce, parallel_map, recursive_reduce]
naivemethods = [recursive_map, recursive_reduce]
parmapmethods = [parallel_map, recursive_reduce]
# names = []
sv = [5]
# for sv in [3,4,5,7, 10,12,15,20,21,25,28, 30,35,40,45,50,55,60,70, 80, 100, 120, 150, 200, 250,300, 350,400, 450, 500]:
for sv in [50,100,150]:
# for sv in [200,300,400]:
    for fn in fs:
        print('\n',fn, sv)
        if (fn, str(sv)) not in [(x[0], re.findall(r'[0-9]+', x[1])[0]) for x in  csdfs]:
            print('proceeding')
            csdfs.append((fn, 'par'+str(sv), try_do("highLevel/"+fn, parmethods, [sv] * 10)))
            print('par done')
            csdfs.append((fn, 'naive'+str(sv), try_do("highLevel/"+fn, naivemethods, [sv] * 10)))
            print('naive done')
            csdfs.append((fn, 'parreduce'+str(sv), try_do("highLevel/"+fn, parreducemethods, [sv] * 10)))
            print('parreduce done')
            csdfs.append((fn, 'parmap'+str(sv), try_do("highLevel/"+fn, parmapmethods, [sv] * 10)))
            print('parmap done')
#         w zip
#         csdfs.append((fn, 'par'+str(sv)+"_dz", try_do("highLevel/"+fn, [discrete_zip]+parmethods, [sv] * 10)))
#         csdfs.append((fn, 'naive'+str(sv)+"_dz", try_do("highLevel/"+fn, [discrete_zip]+naivemethods, [sv] * 10)))
#         csdfs.append((fn, 'parreduce'+str(sv)+"_dz", try_do("highLevel/"+fn, [discrete_zip]+parreducemethods, [sv] * 10)))
#         csdfs.append((fn, 'parmap'+str(sv)+"_dz", try_do("highLevel/"+fn, [discrete_zip]+parmapmethods, [sv] * 10)))

print('\n\n\n\n\n Complete')
csdfs = [x for x in csdfs if x[2] != False]
# printls(csdfs)
csdfs += [(x[0], x[1]+"_dz", discrete_zip(copy.deepcopy(x[2]['graph']), None)) for x in csdfs]
print('Discrete Zip complete')

print('\n\n\n\n\n Complete')
csdfs = [x for x in csdfs if x[2] != False]
# printls(csdfs)
extras = []
for x in csdfs:
    if 'dz' not in x[1]:
        print(x[0], x[1])
        csdf_copy = copy.deepcopy(x[2]['graph'])
        discrete_zip(csdf_copy, None)
        extras.append((x[0],  x[1]+"_dz", csdf_copy))
# csdfs += [(x[0], x[1]+"_dz", discrete_zip(copy.deepcopy(x[2]['graph']), None)) for x in csdfs]
csdfs += extras
print('Discrete Zip complete')
ddcsdfs = [(a[0], a[1], b) for a, b in dict([((x[0], x[1]), x[2]) for x in csdfs]).items()]



for csdf in csdfs:
    nbase =  'curr/'+csdf[0]+"_"+csdf[1]
    n1 =nbase+'_.xml'
    write_csdf(csdf[2]['graph'], n1)
    print("Written",n1)
    smushed = compose_maps(csdf[2]['graph'])
    n2 = nbase+'_cmap_.xml'
    write_csdf(smushed, n2)
    print("Written",n2)
    names += [n1,n2]
    
print('\n\n\n\n\n Finished')
# Out:
#  mappy 50
# par done
# naive done
# parreduce done
# parmap done
#
#  userfun 50
# par done
# naive done
# parreduce done
# parmap done
#
#  gemvN 50
# par done
# naive done
# parreduce done
# parmap done
#
#  mydotsmol 50
# par done
# naive done
# parreduce done
# parmap done
#
#  dot 50
# par done
# naive done
# parreduce done
# parmap done
#
#  nbody 50
# par done
# naive done
# parreduce done
# parmap done
#
#  gemvT 50
# par done
# naive done
# parreduce done
# parmap done
#
#  molecularDynamics 50
#
# Couldn't get CSDF for highLevel/molecularDynamics
# 'Unknown' object has no attribute 'length'
# par done
#
# Couldn't get CSDF for highLevel/molecularDynamics
# 'Unknown' object has no attribute 'length'
# naive done
#
# Couldn't get CSDF for highLevel/molecularDynamics
# 'Unknown' object has no attribute 'length'
# parreduce done
#
# Couldn't get CSDF for highLevel/molecularDynamics
# 'Unknown' object has no attribute 'length'
# parmap done
#
#  mriqComputeQ 50
# par done
# naive done
# parreduce done
# parmap done
#
#  mandelbrot 50
# par done
# naive done
# parreduce done
# parmap done
#
#  addlisttoarray 50
# par done
# naive done
# parreduce done
# parmap done
#
#  mydot 50
# par done
# naive done
# parreduce done
# parmap done
#
#  blackScholes 50
# par done
# naive done
# parreduce done
# parmap done
#
#  mriqPhiMag 50
# par done
# naive done
# parreduce done
# parmap done
#
#  asum 50
# par done
# naive done
# parreduce done
# parmap done
#
#  mv 50
# par done
# naive done
# parreduce done
# parmap done
#
#  nearestNeighbour 50
# par done
# naive done
# parreduce done
# parmap done
#
#  scal 50
# par done
# naive done
# parreduce done
# parmap done
#
#  mvAsMM 50
# par done
# naive done
# parreduce done
# parmap done
#
#  kmeans 50
# ERROR ERROR ERROR
#
# Couldn't get CSDF for highLevel/kmeans
# 'Unknown' object has no attribute 'length'
# par done
# ERROR ERROR ERROR
#
# Couldn't get CSDF for highLevel/kmeans
# 'Unknown' object has no attribute 'length'
# naive done
# ERROR ERROR ERROR
#
# Couldn't get CSDF for highLevel/kmeans
# 'Unknown' object has no attribute 'length'
# parreduce done
# ERROR ERROR ERROR
#
# Couldn't get CSDF for highLevel/kmeans
# 'Unknown' object has no attribute 'length'
# parmap done
#
#  mmTN 50
# par done
# naive done
# parreduce done
# parmap done
#
#  mappy 100
# par done
# naive done
# parreduce done
# parmap done
#
#  userfun 100
# par done
# naive done
# parreduce done
# parmap done
#
#  gemvN 100
# par done
# naive done
# parreduce done
# parmap done
#
#  mydotsmol 100
# par done
# naive done
# parreduce done
# parmap done
#
#  dot 100
# par done
# naive done
# parreduce done
# parmap done
#
#  nbody 100
# par done
# naive done
# parreduce done
# parmap done
#
#  gemvT 100
# par done
# naive done
# parreduce done
# parmap done
#
#  molecularDynamics 100
#
# Couldn't get CSDF for highLevel/molecularDynamics
# 'Unknown' object has no attribute 'length'
# par done
#
# Couldn't get CSDF for highLevel/molecularDynamics
# 'Unknown' object has no attribute 'length'
# naive done
#
# Couldn't get CSDF for highLevel/molecularDynamics
# 'Unknown' object has no attribute 'length'
# parreduce done
#
# Couldn't get CSDF for highLevel/molecularDynamics
# 'Unknown' object has no attribute 'length'
# parmap done
#
#  mriqComputeQ 100
# par done
# naive done
# parreduce done
# parmap done
#
#  mandelbrot 100
# par done
# naive done
# parreduce done
# parmap done
#
#  addlisttoarray 100
# par done
# naive done
# parreduce done
# parmap done
#
#  mydot 100
# par done
# naive done
# parreduce done
# parmap done
#
#  blackScholes 100
# par done
# naive done
# parreduce done
# parmap done
#
#  mriqPhiMag 100
# par done
# naive done
# parreduce done
# parmap done
#
#  asum 100
# par done
# naive done
# parreduce done
# parmap done
#
#  mv 100
# par done
# naive done
# parreduce done
# parmap done
#
#  nearestNeighbour 100
# par done
# naive done
# parreduce done
# parmap done
#
#  scal 100
# par done
# naive done
# parreduce done
# parmap done
#
#  mvAsMM 100
# par done
# naive done
# parreduce done
# parmap done
#
#  kmeans 100
# ERROR ERROR ERROR
#
# Couldn't get CSDF for highLevel/kmeans
# 'Unknown' object has no attribute 'length'
# par done
# ERROR ERROR ERROR
#
# Couldn't get CSDF for highLevel/kmeans
# 'Unknown' object has no attribute 'length'
# naive done
# ERROR ERROR ERROR
#
# Couldn't get CSDF for highLevel/kmeans
# 'Unknown' object has no attribute 'length'
# parreduce done
# ERROR ERROR ERROR
#
# Couldn't get CSDF for highLevel/kmeans
# 'Unknown' object has no attribute 'length'
# parmap done
#
#  mmTN 100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-282d8dca10b1> in <module>
#      16     for fn in fs:
#      17         print('\n',fn, sv)
# ---> 18         csdfs.append((fn, 'par'+str(sv), try_do("highLevel/"+fn, parmethods, [sv] * 10)))
#      19         print('par done')
#      20         csdfs.append((fn, 'naive'+str(sv), try_do("highLevel/"+fn, naivemethods, [sv] * 10)))
#
# <ipython-input-1-5860133b4107> in try_do(filename, methods, sizevar_file)
#      27         p = parse_file(filename, sizevar_file)
#      28         g = p['graph']
# ---> 29         exploder(methods)(g)
#      30         add_dt_to_channels(p)
#      31         check_correct(g)
#
# <ipython-input-1-aab3ce133dea> in <lambda>(g)
#       4
#       5 def exploder(methods):
# ----> 6     return lambda g: explode(g, methods)
#       7
#       8 def explode(graph, methods):
#
# <ipython-input-1-aab3ce133dea> in explode(graph, methods)
#       8 def explode(graph, methods):
#       9     for method in methods:
# ---> 10         method(graph, exploder(methods))
#      11 #         c
#      12     return graph
#
# <ipython-input-1-aab3ce133dea> in parallel_map(graph, explode_method, groupsize)
#     110         nodes += [da, ra, jnr, spl]
#     111         subgraph = explode_method(node.subfunc)
# --> 112         externals = [c.src_act for c in subgraph['channels'] if c.src_act not in [n.name for n in subgraph['nodes']]]
#     113         externals = [n for n in nodes if n.name in externals]
#     114         count = 0
#
# <ipython-input-1-aab3ce133dea> in <listcomp>(.0)
#     110         nodes += [da, ra, jnr, spl]
#     111         subgraph = explode_method(node.subfunc)
# --> 112         externals = [c.src_act for c in subgraph['channels'] if c.src_act not in [n.name for n in subgraph['nodes']]]
#     113         externals = [n for n in nodes if n.name in externals]
#     114         count = 0
#
# <ipython-input-1-aab3ce133dea> in <listcomp>(.0)
#     110         nodes += [da, ra, jnr, spl]
#     111         subgraph = explode_method(node.subfunc)
# --> 112         externals = [c.src_act for c in subgraph['channels'] if c.src_act not in [n.name for n in subgraph['nodes']]]
#     113         externals = [n for n in nodes if n.name in externals]
#     114         count = 0
#
# KeyboardInterrupt:

# %%
print('\n\n\n\n\n Complete')
csdfs = [x for x in csdfs if x[2] != False]
# printls(csdfs)
extras = []
for x in csdfs:
    if 'dz' not in x[1]:
        print(x[0], x[1])
        csdf_copy = copy.deepcopy(x[2]['graph'])
        discrete_zip(csdf_copy, None)
        extras.append((x[0],  x[1]+"_dz", csdf_copy))
# csdfs += [(x[0], x[1]+"_dz", discrete_zip(copy.deepcopy(x[2]['graph']), None)) for x in csdfs]
csdfs += extras
print('Discrete Zip complete')
ddcsdfs = [(a[0], a[1], b) for a, b in dict([((x[0], x[1]), x[2]) for x in csdfs]).items()]

for csdf in ddcsdfs:
    g = csdf[2] if 'dz' in csdf[1] else csdf[2]['graph']
    nbase =  'curr/'+csdf[0]+"_"+csdf[1]
    n1 =nbase+'_.xml'
    write_csdf(g, n1)
    print("Written",n1)
    smushed = compose_maps(g)
    n2 = nbase+'_cmap_.xml'
    write_csdf(smushed, n2)
    print("Written",n2)
    names += [n1,n2]
# Out:
#  Complete
# mappy par3
# mappy naive3
# mappy parreduce3
# mappy parmap3
# userfun par3
# userfun naive3
# userfun parreduce3
# userfun parmap3
# gemvN par3
# gemvN naive3
# gemvN parreduce3
# gemvN parmap3
# mydotsmol par3
# mydotsmol naive3
# mydotsmol parreduce3
# mydotsmol parmap3
# dot par3
# dot naive3
# dot parreduce3
# dot parmap3
# nbody par3
# nbody naive3
# nbody parreduce3
# nbody parmap3
# gemvT par3
# gemvT naive3
# gemvT parreduce3
# gemvT parmap3
# mriqComputeQ par3
# mriqComputeQ naive3
# mriqComputeQ parreduce3
# mriqComputeQ parmap3
# mandelbrot par3
# mandelbrot naive3
# mandelbrot parreduce3
# mandelbrot parmap3
# addlisttoarray par3
# addlisttoarray naive3
# addlisttoarray parreduce3
# addlisttoarray parmap3
# mydot par3
# mydot naive3
# mydot parreduce3
# mydot parmap3
# blackScholes par3
# blackScholes naive3
# blackScholes parreduce3
# blackScholes parmap3
# mriqPhiMag par3
# mriqPhiMag naive3
# mriqPhiMag parreduce3
# mriqPhiMag parmap3
# asum par3
# asum naive3
# asum parreduce3
# asum parmap3
# mv par3
# mv naive3
# mv parreduce3
# mv parmap3
# nearestNeighbour par3
# nearestNeighbour naive3
# nearestNeighbour parreduce3
# nearestNeighbour parmap3
# scal par3
# scal naive3
# scal parreduce3
# scal parmap3
# mvAsMM par3
# mvAsMM naive3
# mvAsMM parreduce3
# mvAsMM parmap3
# mmTN par3
# mmTN naive3
# mmTN parreduce3
# mmTN parmap3
# mappy par5
# mappy naive5
# mappy parreduce5
# mappy parmap5
# userfun par5
# userfun naive5
# userfun parreduce5
# userfun parmap5
# gemvN par5
# gemvN naive5
# gemvN parreduce5
# gemvN parmap5
# mydotsmol par5
# mydotsmol naive5
# mydotsmol parreduce5
# mydotsmol parmap5
# dot par5
# dot naive5
# dot parreduce5
# dot parmap5
# nbody par5
# nbody naive5
# nbody parreduce5
# nbody parmap5
# gemvT par5
# gemvT naive5
# gemvT parreduce5
# gemvT parmap5
# mriqComputeQ par5
# mriqComputeQ naive5
# mriqComputeQ parreduce5
# mriqComputeQ parmap5
# mandelbrot par5
# mandelbrot naive5
# mandelbrot parreduce5
# mandelbrot parmap5
# addlisttoarray par5
# addlisttoarray naive5
# addlisttoarray parreduce5
# addlisttoarray parmap5
# mydot par5
# mydot naive5
# mydot parreduce5
# mydot parmap5
# blackScholes par5
# blackScholes naive5
# blackScholes parreduce5
# blackScholes parmap5
# mriqPhiMag par5
# mriqPhiMag naive5
# mriqPhiMag parreduce5
# mriqPhiMag parmap5
# asum par5
# asum naive5
# asum parreduce5
# asum parmap5
# mv par5
# mv naive5
# mv parreduce5
# mv parmap5
# nearestNeighbour par5
# nearestNeighbour naive5
# nearestNeighbour parreduce5
# nearestNeighbour parmap5
# scal par5
# scal naive5
# scal parreduce5
# scal parmap5
# mvAsMM par5
# mvAsMM naive5
# mvAsMM parreduce5
# mvAsMM parmap5
# mmTN par5
# mmTN naive5
# mmTN parreduce5
# mmTN parmap5
# mappy par7
# mappy naive7
# mappy parreduce7
# mappy parmap7
# userfun par7
# userfun naive7
# userfun parreduce7
# userfun parmap7
# gemvN par7
# gemvN naive7
# gemvN parreduce7
# gemvN parmap7
# mydotsmol par7
# mydotsmol naive7
# mydotsmol parreduce7
# mydotsmol parmap7
# dot par7
# dot naive7
# dot parreduce7
# dot parmap7
# nbody par7
# nbody naive7
# nbody parreduce7
# nbody parmap7
# gemvT par7
# gemvT naive7
# gemvT parreduce7
# gemvT parmap7
# mriqComputeQ par7
# mriqComputeQ naive7
# mriqComputeQ parreduce7
# mriqComputeQ parmap7
# mandelbrot par7
# mandelbrot naive7
# mandelbrot parreduce7
# mandelbrot parmap7
# addlisttoarray par7
# addlisttoarray naive7
# addlisttoarray parreduce7
# addlisttoarray parmap7
# mydot par7
# mydot naive7
# mydot parreduce7
# mydot parmap7
# blackScholes par7
# blackScholes naive7
# blackScholes parreduce7
# blackScholes parmap7
# mriqPhiMag par7
# mriqPhiMag naive7
# mriqPhiMag parreduce7
# mriqPhiMag parmap7
# asum par7
# asum naive7
# asum parreduce7
# asum parmap7
# mv par7
# mv naive7
# mv parreduce7
# mv parmap7
# nearestNeighbour par7
# nearestNeighbour naive7
# nearestNeighbour parreduce7
# nearestNeighbour parmap7
# scal par7
# scal naive7
# scal parreduce7
# scal parmap7
# mvAsMM par7
# mvAsMM naive7
# mvAsMM parreduce7
# mvAsMM parmap7
# mmTN par7
# mmTN naive7
# mmTN parreduce7
# mmTN parmap7
# mappy par10
# mappy naive10
# mappy parreduce10
# mappy parmap10
# userfun par10
# userfun naive10
# userfun parreduce10
# userfun parmap10
# gemvN par10
# gemvN naive10
# gemvN parreduce10
# gemvN parmap10
# mydotsmol par10
# mydotsmol naive10
# mydotsmol parreduce10
# mydotsmol parmap10
# dot par10
# dot naive10
# dot parreduce10
# dot parmap10
# nbody par10
# nbody naive10
# nbody parreduce10
# nbody parmap10
# gemvT par10
# gemvT naive10
# gemvT parreduce10
# gemvT parmap10
# mriqComputeQ par10
# mriqComputeQ naive10
# mriqComputeQ parreduce10
# mriqComputeQ parmap10
# mandelbrot par10
# mandelbrot naive10
# mandelbrot parreduce10
# mandelbrot parmap10
# addlisttoarray par10
# addlisttoarray naive10
# addlisttoarray parreduce10
# addlisttoarray parmap10
# mydot par10
# mydot naive10
# mydot parreduce10
# mydot parmap10
# blackScholes par10
# blackScholes naive10
# blackScholes parreduce10
# blackScholes parmap10
# mriqPhiMag par10
# mriqPhiMag naive10
# mriqPhiMag parreduce10
# mriqPhiMag parmap10
# asum par10
# asum naive10
# asum parreduce10
# asum parmap10
# mv par10
# mv naive10
# mv parreduce10
# mv parmap10
# nearestNeighbour par10
# nearestNeighbour naive10
# nearestNeighbour parreduce10
# nearestNeighbour parmap10
# scal par10
# scal naive10
# scal parreduce10
# scal parmap10
# mvAsMM par10
# mvAsMM naive10
# mvAsMM parreduce10
# mvAsMM parmap10
# mmTN par10
# mmTN naive10
# mmTN parreduce10
# mmTN parmap10
# mappy par15
# mappy naive15
# mappy parreduce15
# mappy parmap15
# userfun par15
# userfun naive15
# userfun parreduce15
# userfun parmap15
# gemvN par15
# gemvN naive15
# gemvN parreduce15
# gemvN parmap15
# mydotsmol par15
# mydotsmol naive15
# mydotsmol parreduce15
# mydotsmol parmap15
# dot par15
# dot naive15
# dot parreduce15
# dot parmap15
# nbody par15
# nbody naive15
# nbody parreduce15
# nbody parmap15
# gemvT par15
# gemvT naive15
# gemvT parreduce15
# gemvT parmap15
# mriqComputeQ par15
# mriqComputeQ naive15
# mriqComputeQ parreduce15
# mriqComputeQ parmap15
# mandelbrot par15
# mandelbrot naive15
# mandelbrot parreduce15
# mandelbrot parmap15
# addlisttoarray par15
# addlisttoarray naive15
# addlisttoarray parreduce15
# addlisttoarray parmap15
# mydot par15
# mydot naive15
# mydot parreduce15
# mydot parmap15
# blackScholes par15
# blackScholes naive15
# blackScholes parreduce15
# blackScholes parmap15
# mriqPhiMag par15
# mriqPhiMag naive15
# mriqPhiMag parreduce15
# mriqPhiMag parmap15
# asum par15
# asum naive15
# asum parreduce15
# asum parmap15
# mv par15
# mv naive15
# mv parreduce15
# mv parmap15
# nearestNeighbour par15
# nearestNeighbour naive15
# nearestNeighbour parreduce15
# nearestNeighbour parmap15
# scal par15
# scal naive15
# scal parreduce15
# scal parmap15
# mvAsMM par15
# mvAsMM naive15
# mvAsMM parreduce15
# mvAsMM parmap15
# mmTN par15
# mmTN naive15
# mmTN parreduce15
# mmTN parmap15
# mappy par50
# mappy naive50
# mappy parreduce50
# mappy parmap50
# userfun par50
# userfun naive50
# userfun parreduce50
# userfun parmap50
# gemvN par50
# gemvN naive50
# gemvN parreduce50
# gemvN parmap50
# mydotsmol par50
# mydotsmol naive50
# mydotsmol parreduce50
# mydotsmol parmap50
# dot par50
# dot naive50
# dot parreduce50
# dot parmap50
# nbody par50
# nbody naive50
# nbody parreduce50
# nbody parmap50
# gemvT par50
# gemvT naive50
# gemvT parreduce50
# gemvT parmap50
# mriqComputeQ par50
# mriqComputeQ naive50
# mriqComputeQ parreduce50
# mriqComputeQ parmap50
# mandelbrot par50
# mandelbrot naive50
# mandelbrot parreduce50
# mandelbrot parmap50
# addlisttoarray par50
# addlisttoarray naive50
# addlisttoarray parreduce50
# addlisttoarray parmap50
# mydot par50
# mydot naive50
# mydot parreduce50
# mydot parmap50
# blackScholes par50
# blackScholes naive50
# blackScholes parreduce50
# blackScholes parmap50
# mriqPhiMag par50
# mriqPhiMag naive50
# mriqPhiMag parreduce50
# mriqPhiMag parmap50
# asum par50
# asum naive50
# asum parreduce50
# asum parmap50
# mv par50
# mv naive50
# mv parreduce50
# mv parmap50
# nearestNeighbour par50
# nearestNeighbour naive50
# nearestNeighbour parreduce50
# nearestNeighbour parmap50
# scal par50
# scal naive50
# scal parreduce50
# scal parmap50
# mvAsMM par50
# mvAsMM naive50
# mvAsMM parreduce50
# mvAsMM parmap50
# mmTN par50
# mmTN naive50
# mmTN parreduce50
# mmTN parmap50
# mappy par100
# mappy naive100
# mappy parreduce100
# mappy parmap100
# userfun par100
# userfun naive100
# userfun parreduce100
# userfun parmap100
# gemvN par100
# gemvN naive100
# gemvN parreduce100
# gemvN parmap100
# mydotsmol par100
# mydotsmol naive100
# mydotsmol parreduce100
# mydotsmol parmap100
# dot par100
# dot naive100
# dot parreduce100
# dot parmap100
# nbody par100
# nbody naive100
# nbody parreduce100
# nbody parmap100
# gemvT par100
# gemvT naive100
# gemvT parreduce100
# gemvT parmap100
# mriqComputeQ par100
# mriqComputeQ naive100
# mriqComputeQ parreduce100
# mriqComputeQ parmap100
# mandelbrot par100
# mandelbrot naive100
# mandelbrot parreduce100
# mandelbrot parmap100
# addlisttoarray par100
# addlisttoarray naive100
# addlisttoarray parreduce100
# addlisttoarray parmap100
# mydot par100
# mydot naive100
# mydot parreduce100
# mydot parmap100
# blackScholes par100
# blackScholes naive100
# blackScholes parreduce100
# blackScholes parmap100
# mriqPhiMag par100
# mriqPhiMag naive100
# mriqPhiMag parreduce100
# mriqPhiMag parmap100
# asum par100
# asum naive100
# asum parreduce100
# asum parmap100
# mv par100
# mv naive100
# mv parreduce100
# mv parmap100
# nearestNeighbour par100
# nearestNeighbour naive100
# nearestNeighbour parreduce100
# nearestNeighbour parmap100
# scal par100
# scal naive100
# scal parreduce100
# scal parmap100
# mvAsMM par100
# mvAsMM naive100
# mvAsMM parreduce100
# mvAsMM parmap100
# Discrete Zip complete
# Written curr/mappy_par3_.xml
# Written curr/mappy_par3_cmap_.xml
# Written curr/mappy_naive3_.xml
# Written curr/mappy_naive3_cmap_.xml
# Written curr/mappy_parreduce3_.xml
# Written curr/mappy_parreduce3_cmap_.xml
# Written curr/mappy_parmap3_.xml
# Written curr/mappy_parmap3_cmap_.xml
# Written curr/userfun_par3_.xml
# Written curr/userfun_par3_cmap_.xml
# Written curr/userfun_naive3_.xml
# Written curr/userfun_naive3_cmap_.xml
# Written curr/userfun_parreduce3_.xml
# Written curr/userfun_parreduce3_cmap_.xml
# Written curr/userfun_parmap3_.xml
# Written curr/userfun_parmap3_cmap_.xml
# Written curr/gemvN_par3_.xml
# Written curr/gemvN_par3_cmap_.xml
# Written curr/gemvN_naive3_.xml
# Written curr/gemvN_naive3_cmap_.xml
# Written curr/gemvN_parreduce3_.xml
# Written curr/gemvN_parreduce3_cmap_.xml
# Written curr/gemvN_parmap3_.xml
# Written curr/gemvN_parmap3_cmap_.xml
# Written curr/mydotsmol_par3_.xml
# Written curr/mydotsmol_par3_cmap_.xml
# Written curr/mydotsmol_naive3_.xml
# Written curr/mydotsmol_naive3_cmap_.xml
# Written curr/mydotsmol_parreduce3_.xml
# Written curr/mydotsmol_parreduce3_cmap_.xml
# Written curr/mydotsmol_parmap3_.xml
# Written curr/mydotsmol_parmap3_cmap_.xml
# Written curr/dot_par3_.xml
# Written curr/dot_par3_cmap_.xml
# Written curr/dot_naive3_.xml
# Written curr/dot_naive3_cmap_.xml
# Written curr/dot_parreduce3_.xml
# Written curr/dot_parreduce3_cmap_.xml
# Written curr/dot_parmap3_.xml
# Written curr/dot_parmap3_cmap_.xml
# Written curr/nbody_par3_.xml
# Written curr/nbody_par3_cmap_.xml
# Written curr/nbody_naive3_.xml
# Written curr/nbody_naive3_cmap_.xml
# Written curr/nbody_parreduce3_.xml
# Written curr/nbody_parreduce3_cmap_.xml
# Written curr/nbody_parmap3_.xml
# Written curr/nbody_parmap3_cmap_.xml
# Written curr/gemvT_par3_.xml
# Written curr/gemvT_par3_cmap_.xml
# Written curr/gemvT_naive3_.xml
# Written curr/gemvT_naive3_cmap_.xml
# Written curr/gemvT_parreduce3_.xml
# Written curr/gemvT_parreduce3_cmap_.xml
# Written curr/gemvT_parmap3_.xml
# Written curr/gemvT_parmap3_cmap_.xml
# Written curr/mriqComputeQ_par3_.xml
# Written curr/mriqComputeQ_par3_cmap_.xml
# Written curr/mriqComputeQ_naive3_.xml
# Written curr/mriqComputeQ_naive3_cmap_.xml
# Written curr/mriqComputeQ_parreduce3_.xml
# Written curr/mriqComputeQ_parreduce3_cmap_.xml
# Written curr/mriqComputeQ_parmap3_.xml
# Written curr/mriqComputeQ_parmap3_cmap_.xml
# Written curr/mandelbrot_par3_.xml
# Written curr/mandelbrot_par3_cmap_.xml
# Written curr/mandelbrot_naive3_.xml
# Written curr/mandelbrot_naive3_cmap_.xml
# Written curr/mandelbrot_parreduce3_.xml
# Written curr/mandelbrot_parreduce3_cmap_.xml
# Written curr/mandelbrot_parmap3_.xml
# Written curr/mandelbrot_parmap3_cmap_.xml
# Written curr/addlisttoarray_par3_.xml
# Written curr/addlisttoarray_par3_cmap_.xml
# Written curr/addlisttoarray_naive3_.xml
# Written curr/addlisttoarray_naive3_cmap_.xml
# Written curr/addlisttoarray_parreduce3_.xml
# Written curr/addlisttoarray_parreduce3_cmap_.xml
# Written curr/addlisttoarray_parmap3_.xml
# Written curr/addlisttoarray_parmap3_cmap_.xml
# Written curr/mydot_par3_.xml
# Written curr/mydot_par3_cmap_.xml
# Written curr/mydot_naive3_.xml
# Written curr/mydot_naive3_cmap_.xml
# Written curr/mydot_parreduce3_.xml
# Written curr/mydot_parreduce3_cmap_.xml
# Written curr/mydot_parmap3_.xml
# Written curr/mydot_parmap3_cmap_.xml
# Written curr/blackScholes_par3_.xml
# Written curr/blackScholes_par3_cmap_.xml
# Written curr/blackScholes_naive3_.xml
# Written curr/blackScholes_naive3_cmap_.xml
# Written curr/blackScholes_parreduce3_.xml
# Written curr/blackScholes_parreduce3_cmap_.xml
# Written curr/blackScholes_parmap3_.xml
# Written curr/blackScholes_parmap3_cmap_.xml
# Written curr/mriqPhiMag_par3_.xml
# Written curr/mriqPhiMag_par3_cmap_.xml
# Written curr/mriqPhiMag_naive3_.xml
# Written curr/mriqPhiMag_naive3_cmap_.xml
# Written curr/mriqPhiMag_parreduce3_.xml
# Written curr/mriqPhiMag_parreduce3_cmap_.xml
# Written curr/mriqPhiMag_parmap3_.xml
# Written curr/mriqPhiMag_parmap3_cmap_.xml
# Written curr/asum_par3_.xml
# Written curr/asum_par3_cmap_.xml
# Written curr/asum_naive3_.xml
# Written curr/asum_naive3_cmap_.xml
# Written curr/asum_parreduce3_.xml
# Written curr/asum_parreduce3_cmap_.xml
# Written curr/asum_parmap3_.xml
# Written curr/asum_parmap3_cmap_.xml
# Written curr/mv_par3_.xml
# Written curr/mv_par3_cmap_.xml
# Written curr/mv_naive3_.xml
# Written curr/mv_naive3_cmap_.xml
# Written curr/mv_parreduce3_.xml
# Written curr/mv_parreduce3_cmap_.xml
# Written curr/mv_parmap3_.xml
# Written curr/mv_parmap3_cmap_.xml
# Written curr/nearestNeighbour_par3_.xml
# Written curr/nearestNeighbour_par3_cmap_.xml
# Written curr/nearestNeighbour_naive3_.xml
# Written curr/nearestNeighbour_naive3_cmap_.xml
# Written curr/nearestNeighbour_parreduce3_.xml
# Written curr/nearestNeighbour_parreduce3_cmap_.xml
# Written curr/nearestNeighbour_parmap3_.xml
# Written curr/nearestNeighbour_parmap3_cmap_.xml
# Written curr/scal_par3_.xml
# Written curr/scal_par3_cmap_.xml
# Written curr/scal_naive3_.xml
# Written curr/scal_naive3_cmap_.xml
# Written curr/scal_parreduce3_.xml
# Written curr/scal_parreduce3_cmap_.xml
# Written curr/scal_parmap3_.xml
# Written curr/scal_parmap3_cmap_.xml
# Written curr/mvAsMM_par3_.xml
# Written curr/mvAsMM_par3_cmap_.xml
# Written curr/mvAsMM_naive3_.xml
# Written curr/mvAsMM_naive3_cmap_.xml
# Written curr/mvAsMM_parreduce3_.xml
# Written curr/mvAsMM_parreduce3_cmap_.xml
# Written curr/mvAsMM_parmap3_.xml
# Written curr/mvAsMM_parmap3_cmap_.xml
# Written curr/mmTN_par3_.xml
# Written curr/mmTN_par3_cmap_.xml
# Written curr/mmTN_naive3_.xml
# Written curr/mmTN_naive3_cmap_.xml
# Written curr/mmTN_parreduce3_.xml
# Written curr/mmTN_parreduce3_cmap_.xml
# Written curr/mmTN_parmap3_.xml
# Written curr/mmTN_parmap3_cmap_.xml
# Written curr/mappy_par5_.xml
# Written curr/mappy_par5_cmap_.xml
# Written curr/mappy_naive5_.xml
# Written curr/mappy_naive5_cmap_.xml
# Written curr/mappy_parreduce5_.xml
# Written curr/mappy_parreduce5_cmap_.xml
# Written curr/mappy_parmap5_.xml
# Written curr/mappy_parmap5_cmap_.xml
# Written curr/userfun_par5_.xml
# Written curr/userfun_par5_cmap_.xml
# Written curr/userfun_naive5_.xml
# Written curr/userfun_naive5_cmap_.xml
# Written curr/userfun_parreduce5_.xml
# Written curr/userfun_parreduce5_cmap_.xml
# Written curr/userfun_parmap5_.xml
# Written curr/userfun_parmap5_cmap_.xml
# Written curr/gemvN_par5_.xml
# Written curr/gemvN_par5_cmap_.xml
# Written curr/gemvN_naive5_.xml
# Written curr/gemvN_naive5_cmap_.xml
# Written curr/gemvN_parreduce5_.xml
# Written curr/gemvN_parreduce5_cmap_.xml
# Written curr/gemvN_parmap5_.xml
# Written curr/gemvN_parmap5_cmap_.xml
# Written curr/mydotsmol_par5_.xml
# Written curr/mydotsmol_par5_cmap_.xml
# Written curr/mydotsmol_naive5_.xml
# Written curr/mydotsmol_naive5_cmap_.xml
# Written curr/mydotsmol_parreduce5_.xml
# Written curr/mydotsmol_parreduce5_cmap_.xml
# Written curr/mydotsmol_parmap5_.xml
# Written curr/mydotsmol_parmap5_cmap_.xml
# Written curr/dot_par5_.xml
# Written curr/dot_par5_cmap_.xml
# Written curr/dot_naive5_.xml
# Written curr/dot_naive5_cmap_.xml
# Written curr/dot_parreduce5_.xml
# Written curr/dot_parreduce5_cmap_.xml
# Written curr/dot_parmap5_.xml
# Written curr/dot_parmap5_cmap_.xml
# Written curr/nbody_par5_.xml
# Written curr/nbody_par5_cmap_.xml
# Written curr/nbody_naive5_.xml
# Written curr/nbody_naive5_cmap_.xml
# Written curr/nbody_parreduce5_.xml
# Written curr/nbody_parreduce5_cmap_.xml
# Written curr/nbody_parmap5_.xml
# Written curr/nbody_parmap5_cmap_.xml
# Written curr/gemvT_par5_.xml
# Written curr/gemvT_par5_cmap_.xml
# Written curr/gemvT_naive5_.xml
# Written curr/gemvT_naive5_cmap_.xml
# Written curr/gemvT_parreduce5_.xml
# Written curr/gemvT_parreduce5_cmap_.xml
# Written curr/gemvT_parmap5_.xml
# Written curr/gemvT_parmap5_cmap_.xml
# Written curr/mriqComputeQ_par5_.xml
# Written curr/mriqComputeQ_par5_cmap_.xml
# Written curr/mriqComputeQ_naive5_.xml
# Written curr/mriqComputeQ_naive5_cmap_.xml
# Written curr/mriqComputeQ_parreduce5_.xml
# Written curr/mriqComputeQ_parreduce5_cmap_.xml
# Written curr/mriqComputeQ_parmap5_.xml
# Written curr/mriqComputeQ_parmap5_cmap_.xml
# Written curr/mandelbrot_par5_.xml
# Written curr/mandelbrot_par5_cmap_.xml
# Written curr/mandelbrot_naive5_.xml
# Written curr/mandelbrot_naive5_cmap_.xml
# Written curr/mandelbrot_parreduce5_.xml
# Written curr/mandelbrot_parreduce5_cmap_.xml
# Written curr/mandelbrot_parmap5_.xml
# Written curr/mandelbrot_parmap5_cmap_.xml
# Written curr/addlisttoarray_par5_.xml
# Written curr/addlisttoarray_par5_cmap_.xml
# Written curr/addlisttoarray_naive5_.xml
# Written curr/addlisttoarray_naive5_cmap_.xml
# Written curr/addlisttoarray_parreduce5_.xml
# Written curr/addlisttoarray_parreduce5_cmap_.xml
# Written curr/addlisttoarray_parmap5_.xml
# Written curr/addlisttoarray_parmap5_cmap_.xml
# Written curr/mydot_par5_.xml
# Written curr/mydot_par5_cmap_.xml
# Written curr/mydot_naive5_.xml
# Written curr/mydot_naive5_cmap_.xml
# Written curr/mydot_parreduce5_.xml
# Written curr/mydot_parreduce5_cmap_.xml
# Written curr/mydot_parmap5_.xml
# Written curr/mydot_parmap5_cmap_.xml
# Written curr/blackScholes_par5_.xml
# Written curr/blackScholes_par5_cmap_.xml
# Written curr/blackScholes_naive5_.xml
# Written curr/blackScholes_naive5_cmap_.xml
# Written curr/blackScholes_parreduce5_.xml
# Written curr/blackScholes_parreduce5_cmap_.xml
# Written curr/blackScholes_parmap5_.xml
# Written curr/blackScholes_parmap5_cmap_.xml
# Written curr/mriqPhiMag_par5_.xml
# Written curr/mriqPhiMag_par5_cmap_.xml
# Written curr/mriqPhiMag_naive5_.xml
# Written curr/mriqPhiMag_naive5_cmap_.xml
# Written curr/mriqPhiMag_parreduce5_.xml
# Written curr/mriqPhiMag_parreduce5_cmap_.xml
# Written curr/mriqPhiMag_parmap5_.xml
# Written curr/mriqPhiMag_parmap5_cmap_.xml
# Written curr/asum_par5_.xml
# Written curr/asum_par5_cmap_.xml
# Written curr/asum_naive5_.xml
# Written curr/asum_naive5_cmap_.xml
# Written curr/asum_parreduce5_.xml
# Written curr/asum_parreduce5_cmap_.xml
# Written curr/asum_parmap5_.xml
# Written curr/asum_parmap5_cmap_.xml
# Written curr/mv_par5_.xml
# Written curr/mv_par5_cmap_.xml
# Written curr/mv_naive5_.xml
# Written curr/mv_naive5_cmap_.xml
# Written curr/mv_parreduce5_.xml
# Written curr/mv_parreduce5_cmap_.xml
# Written curr/mv_parmap5_.xml
# Written curr/mv_parmap5_cmap_.xml
# Written curr/nearestNeighbour_par5_.xml
# Written curr/nearestNeighbour_par5_cmap_.xml
# Written curr/nearestNeighbour_naive5_.xml
# Written curr/nearestNeighbour_naive5_cmap_.xml
# Written curr/nearestNeighbour_parreduce5_.xml
# Written curr/nearestNeighbour_parreduce5_cmap_.xml
# Written curr/nearestNeighbour_parmap5_.xml
# Written curr/nearestNeighbour_parmap5_cmap_.xml
# Written curr/scal_par5_.xml
# Written curr/scal_par5_cmap_.xml
# Written curr/scal_naive5_.xml
# Written curr/scal_naive5_cmap_.xml
# Written curr/scal_parreduce5_.xml
# Written curr/scal_parreduce5_cmap_.xml
# Written curr/scal_parmap5_.xml
# Written curr/scal_parmap5_cmap_.xml
# Written curr/mvAsMM_par5_.xml
# Written curr/mvAsMM_par5_cmap_.xml
# Written curr/mvAsMM_naive5_.xml
# Written curr/mvAsMM_naive5_cmap_.xml
# Written curr/mvAsMM_parreduce5_.xml
# Written curr/mvAsMM_parreduce5_cmap_.xml
# Written curr/mvAsMM_parmap5_.xml
# Written curr/mvAsMM_parmap5_cmap_.xml
# Written curr/mmTN_par5_.xml
# Written curr/mmTN_par5_cmap_.xml
# Written curr/mmTN_naive5_.xml
# Written curr/mmTN_naive5_cmap_.xml
# Written curr/mmTN_parreduce5_.xml
# Written curr/mmTN_parreduce5_cmap_.xml
# Written curr/mmTN_parmap5_.xml
# Written curr/mmTN_parmap5_cmap_.xml
# Written curr/mappy_par7_.xml
# Written curr/mappy_par7_cmap_.xml
# Written curr/mappy_naive7_.xml
# Written curr/mappy_naive7_cmap_.xml
# Written curr/mappy_parreduce7_.xml
# Written curr/mappy_parreduce7_cmap_.xml
# Written curr/mappy_parmap7_.xml
# Written curr/mappy_parmap7_cmap_.xml
# Written curr/userfun_par7_.xml
# Written curr/userfun_par7_cmap_.xml
# Written curr/userfun_naive7_.xml
# Written curr/userfun_naive7_cmap_.xml
# Written curr/userfun_parreduce7_.xml
# Written curr/userfun_parreduce7_cmap_.xml
# Written curr/userfun_parmap7_.xml
# Written curr/userfun_parmap7_cmap_.xml
# Written curr/gemvN_par7_.xml
# Written curr/gemvN_par7_cmap_.xml
# Written curr/gemvN_naive7_.xml
# Written curr/gemvN_naive7_cmap_.xml
# Written curr/gemvN_parreduce7_.xml
# Written curr/gemvN_parreduce7_cmap_.xml
# Written curr/gemvN_parmap7_.xml
# Written curr/gemvN_parmap7_cmap_.xml
# Written curr/mydotsmol_par7_.xml
# Written curr/mydotsmol_par7_cmap_.xml
# Written curr/mydotsmol_naive7_.xml
# Written curr/mydotsmol_naive7_cmap_.xml
# Written curr/mydotsmol_parreduce7_.xml
# Written curr/mydotsmol_parreduce7_cmap_.xml
# Written curr/mydotsmol_parmap7_.xml
# Written curr/mydotsmol_parmap7_cmap_.xml
# Written curr/dot_par7_.xml
# Written curr/dot_par7_cmap_.xml
# Written curr/dot_naive7_.xml
# Written curr/dot_naive7_cmap_.xml
# Written curr/dot_parreduce7_.xml
# Written curr/dot_parreduce7_cmap_.xml
# Written curr/dot_parmap7_.xml
# Written curr/dot_parmap7_cmap_.xml
# Written curr/nbody_par7_.xml
# Written curr/nbody_par7_cmap_.xml
# Written curr/nbody_naive7_.xml
# Written curr/nbody_naive7_cmap_.xml
# Written curr/nbody_parreduce7_.xml
# Written curr/nbody_parreduce7_cmap_.xml
# Written curr/nbody_parmap7_.xml
# Written curr/nbody_parmap7_cmap_.xml
# Written curr/gemvT_par7_.xml
# Written curr/gemvT_par7_cmap_.xml
# Written curr/gemvT_naive7_.xml
# Written curr/gemvT_naive7_cmap_.xml
# Written curr/gemvT_parreduce7_.xml
# Written curr/gemvT_parreduce7_cmap_.xml
# Written curr/gemvT_parmap7_.xml
# Written curr/gemvT_parmap7_cmap_.xml
# Written curr/mriqComputeQ_par7_.xml
# Written curr/mriqComputeQ_par7_cmap_.xml
# Written curr/mriqComputeQ_naive7_.xml
# Written curr/mriqComputeQ_naive7_cmap_.xml
# Written curr/mriqComputeQ_parreduce7_.xml
# Written curr/mriqComputeQ_parreduce7_cmap_.xml
# Written curr/mriqComputeQ_parmap7_.xml
# Written curr/mriqComputeQ_parmap7_cmap_.xml
# Written curr/mandelbrot_par7_.xml
# Written curr/mandelbrot_par7_cmap_.xml
# Written curr/mandelbrot_naive7_.xml
# Written curr/mandelbrot_naive7_cmap_.xml
# Written curr/mandelbrot_parreduce7_.xml
# Written curr/mandelbrot_parreduce7_cmap_.xml
# Written curr/mandelbrot_parmap7_.xml
# Written curr/mandelbrot_parmap7_cmap_.xml
# Written curr/addlisttoarray_par7_.xml
# Written curr/addlisttoarray_par7_cmap_.xml
# Written curr/addlisttoarray_naive7_.xml
# Written curr/addlisttoarray_naive7_cmap_.xml
# Written curr/addlisttoarray_parreduce7_.xml
# Written curr/addlisttoarray_parreduce7_cmap_.xml
# Written curr/addlisttoarray_parmap7_.xml
# Written curr/addlisttoarray_parmap7_cmap_.xml
# Written curr/mydot_par7_.xml
# Written curr/mydot_par7_cmap_.xml
# Written curr/mydot_naive7_.xml
# Written curr/mydot_naive7_cmap_.xml
# Written curr/mydot_parreduce7_.xml
# Written curr/mydot_parreduce7_cmap_.xml
# Written curr/mydot_parmap7_.xml
# Written curr/mydot_parmap7_cmap_.xml
# Written curr/blackScholes_par7_.xml
# Written curr/blackScholes_par7_cmap_.xml
# Written curr/blackScholes_naive7_.xml
# Written curr/blackScholes_naive7_cmap_.xml
# Written curr/blackScholes_parreduce7_.xml
# Written curr/blackScholes_parreduce7_cmap_.xml
# Written curr/blackScholes_parmap7_.xml
# Written curr/blackScholes_parmap7_cmap_.xml
# Written curr/mriqPhiMag_par7_.xml
# Written curr/mriqPhiMag_par7_cmap_.xml
# Written curr/mriqPhiMag_naive7_.xml
# Written curr/mriqPhiMag_naive7_cmap_.xml
# Written curr/mriqPhiMag_parreduce7_.xml
# Written curr/mriqPhiMag_parreduce7_cmap_.xml
# Written curr/mriqPhiMag_parmap7_.xml
# Written curr/mriqPhiMag_parmap7_cmap_.xml
# Written curr/asum_par7_.xml
# Written curr/asum_par7_cmap_.xml
# Written curr/asum_naive7_.xml
# Written curr/asum_naive7_cmap_.xml
# Written curr/asum_parreduce7_.xml
# Written curr/asum_parreduce7_cmap_.xml
# Written curr/asum_parmap7_.xml
# Written curr/asum_parmap7_cmap_.xml
# Written curr/mv_par7_.xml
# Written curr/mv_par7_cmap_.xml
# Written curr/mv_naive7_.xml
# Written curr/mv_naive7_cmap_.xml
# Written curr/mv_parreduce7_.xml
# Written curr/mv_parreduce7_cmap_.xml
# Written curr/mv_parmap7_.xml
# Written curr/mv_parmap7_cmap_.xml
# Written curr/nearestNeighbour_par7_.xml
# Written curr/nearestNeighbour_par7_cmap_.xml
# Written curr/nearestNeighbour_naive7_.xml
# Written curr/nearestNeighbour_naive7_cmap_.xml
# Written curr/nearestNeighbour_parreduce7_.xml
# Written curr/nearestNeighbour_parreduce7_cmap_.xml
# Written curr/nearestNeighbour_parmap7_.xml
# Written curr/nearestNeighbour_parmap7_cmap_.xml
# Written curr/scal_par7_.xml
# Written curr/scal_par7_cmap_.xml
# Written curr/scal_naive7_.xml
# Written curr/scal_naive7_cmap_.xml
# Written curr/scal_parreduce7_.xml
# Written curr/scal_parreduce7_cmap_.xml
# Written curr/scal_parmap7_.xml
# Written curr/scal_parmap7_cmap_.xml
# Written curr/mvAsMM_par7_.xml
# Written curr/mvAsMM_par7_cmap_.xml
# Written curr/mvAsMM_naive7_.xml
# Written curr/mvAsMM_naive7_cmap_.xml
# Written curr/mvAsMM_parreduce7_.xml
# Written curr/mvAsMM_parreduce7_cmap_.xml
# Written curr/mvAsMM_parmap7_.xml
# Written curr/mvAsMM_parmap7_cmap_.xml
# Written curr/mmTN_par7_.xml
# Written curr/mmTN_par7_cmap_.xml
# Written curr/mmTN_naive7_.xml
# Written curr/mmTN_naive7_cmap_.xml
# Written curr/mmTN_parreduce7_.xml
# Written curr/mmTN_parreduce7_cmap_.xml
# Written curr/mmTN_parmap7_.xml
# Written curr/mmTN_parmap7_cmap_.xml
# Written curr/mappy_par10_.xml
# Written curr/mappy_par10_cmap_.xml
# Written curr/mappy_naive10_.xml
# Written curr/mappy_naive10_cmap_.xml
# Written curr/mappy_parreduce10_.xml
# Written curr/mappy_parreduce10_cmap_.xml
# Written curr/mappy_parmap10_.xml
# Written curr/mappy_parmap10_cmap_.xml
# Written curr/userfun_par10_.xml
# Written curr/userfun_par10_cmap_.xml
# Written curr/userfun_naive10_.xml
# Written curr/userfun_naive10_cmap_.xml
# Written curr/userfun_parreduce10_.xml
# Written curr/userfun_parreduce10_cmap_.xml
# Written curr/userfun_parmap10_.xml
# Written curr/userfun_parmap10_cmap_.xml
# Written curr/gemvN_par10_.xml
# Written curr/gemvN_par10_cmap_.xml
# Written curr/gemvN_naive10_.xml
# Written curr/gemvN_naive10_cmap_.xml
# Written curr/gemvN_parreduce10_.xml
# Written curr/gemvN_parreduce10_cmap_.xml
# Written curr/gemvN_parmap10_.xml
# Written curr/gemvN_parmap10_cmap_.xml
# Written curr/mydotsmol_par10_.xml
# Written curr/mydotsmol_par10_cmap_.xml
# Written curr/mydotsmol_naive10_.xml
# Written curr/mydotsmol_naive10_cmap_.xml
# Written curr/mydotsmol_parreduce10_.xml
# Written curr/mydotsmol_parreduce10_cmap_.xml
# Written curr/mydotsmol_parmap10_.xml
# Written curr/mydotsmol_parmap10_cmap_.xml
# Written curr/dot_par10_.xml
# Written curr/dot_par10_cmap_.xml
# Written curr/dot_naive10_.xml
# Written curr/dot_naive10_cmap_.xml
# Written curr/dot_parreduce10_.xml
# Written curr/dot_parreduce10_cmap_.xml
# Written curr/dot_parmap10_.xml
# Written curr/dot_parmap10_cmap_.xml
# Written curr/nbody_par10_.xml
# Written curr/nbody_par10_cmap_.xml
# Written curr/nbody_naive10_.xml
# Written curr/nbody_naive10_cmap_.xml
# Written curr/nbody_parreduce10_.xml
# Written curr/nbody_parreduce10_cmap_.xml
# Written curr/nbody_parmap10_.xml
# Written curr/nbody_parmap10_cmap_.xml
# Written curr/gemvT_par10_.xml
# Written curr/gemvT_par10_cmap_.xml
# Written curr/gemvT_naive10_.xml
# Written curr/gemvT_naive10_cmap_.xml
# Written curr/gemvT_parreduce10_.xml
# Written curr/gemvT_parreduce10_cmap_.xml
# Written curr/gemvT_parmap10_.xml
# Written curr/gemvT_parmap10_cmap_.xml
# Written curr/mriqComputeQ_par10_.xml
# Written curr/mriqComputeQ_par10_cmap_.xml
# Written curr/mriqComputeQ_naive10_.xml
# Written curr/mriqComputeQ_naive10_cmap_.xml
# Written curr/mriqComputeQ_parreduce10_.xml
# Written curr/mriqComputeQ_parreduce10_cmap_.xml
# Written curr/mriqComputeQ_parmap10_.xml
# Written curr/mriqComputeQ_parmap10_cmap_.xml
# Written curr/mandelbrot_par10_.xml
# Written curr/mandelbrot_par10_cmap_.xml
# Written curr/mandelbrot_naive10_.xml
# Written curr/mandelbrot_naive10_cmap_.xml
# Written curr/mandelbrot_parreduce10_.xml
# Written curr/mandelbrot_parreduce10_cmap_.xml
# Written curr/mandelbrot_parmap10_.xml
# Written curr/mandelbrot_parmap10_cmap_.xml
# Written curr/addlisttoarray_par10_.xml
# Written curr/addlisttoarray_par10_cmap_.xml
# Written curr/addlisttoarray_naive10_.xml
# Written curr/addlisttoarray_naive10_cmap_.xml
# Written curr/addlisttoarray_parreduce10_.xml
# Written curr/addlisttoarray_parreduce10_cmap_.xml
# Written curr/addlisttoarray_parmap10_.xml
# Written curr/addlisttoarray_parmap10_cmap_.xml
# Written curr/mydot_par10_.xml
# Written curr/mydot_par10_cmap_.xml
# Written curr/mydot_naive10_.xml
# Written curr/mydot_naive10_cmap_.xml
# Written curr/mydot_parreduce10_.xml
# Written curr/mydot_parreduce10_cmap_.xml
# Written curr/mydot_parmap10_.xml
# Written curr/mydot_parmap10_cmap_.xml
# Written curr/blackScholes_par10_.xml
# Written curr/blackScholes_par10_cmap_.xml
# Written curr/blackScholes_naive10_.xml
# Written curr/blackScholes_naive10_cmap_.xml
# Written curr/blackScholes_parreduce10_.xml
# Written curr/blackScholes_parreduce10_cmap_.xml
# Written curr/blackScholes_parmap10_.xml
# Written curr/blackScholes_parmap10_cmap_.xml
# Written curr/mriqPhiMag_par10_.xml
# Written curr/mriqPhiMag_par10_cmap_.xml
# Written curr/mriqPhiMag_naive10_.xml
# Written curr/mriqPhiMag_naive10_cmap_.xml
# Written curr/mriqPhiMag_parreduce10_.xml
# Written curr/mriqPhiMag_parreduce10_cmap_.xml
# Written curr/mriqPhiMag_parmap10_.xml
# Written curr/mriqPhiMag_parmap10_cmap_.xml
# Written curr/asum_par10_.xml
# Written curr/asum_par10_cmap_.xml
# Written curr/asum_naive10_.xml
# Written curr/asum_naive10_cmap_.xml
# Written curr/asum_parreduce10_.xml
# Written curr/asum_parreduce10_cmap_.xml
# Written curr/asum_parmap10_.xml
# Written curr/asum_parmap10_cmap_.xml
# Written curr/mv_par10_.xml
# Written curr/mv_par10_cmap_.xml
# Written curr/mv_naive10_.xml
# Written curr/mv_naive10_cmap_.xml
# Written curr/mv_parreduce10_.xml
# Written curr/mv_parreduce10_cmap_.xml
# Written curr/mv_parmap10_.xml
# Written curr/mv_parmap10_cmap_.xml
# Written curr/nearestNeighbour_par10_.xml
# Written curr/nearestNeighbour_par10_cmap_.xml
# Written curr/nearestNeighbour_naive10_.xml
# Written curr/nearestNeighbour_naive10_cmap_.xml
# Written curr/nearestNeighbour_parreduce10_.xml
# Written curr/nearestNeighbour_parreduce10_cmap_.xml
# Written curr/nearestNeighbour_parmap10_.xml
# Written curr/nearestNeighbour_parmap10_cmap_.xml
# Written curr/scal_par10_.xml
# Written curr/scal_par10_cmap_.xml
# Written curr/scal_naive10_.xml
# Written curr/scal_naive10_cmap_.xml
# Written curr/scal_parreduce10_.xml
# Written curr/scal_parreduce10_cmap_.xml
# Written curr/scal_parmap10_.xml
# Written curr/scal_parmap10_cmap_.xml
# Written curr/mvAsMM_par10_.xml
# Written curr/mvAsMM_par10_cmap_.xml
# Written curr/mvAsMM_naive10_.xml
# Written curr/mvAsMM_naive10_cmap_.xml
# Written curr/mvAsMM_parreduce10_.xml
# Written curr/mvAsMM_parreduce10_cmap_.xml
# Written curr/mvAsMM_parmap10_.xml
# Written curr/mvAsMM_parmap10_cmap_.xml
# Written curr/mmTN_par10_.xml
# Written curr/mmTN_par10_cmap_.xml
# Written curr/mmTN_naive10_.xml
# Written curr/mmTN_naive10_cmap_.xml
# Written curr/mmTN_parreduce10_.xml
# Written curr/mmTN_parreduce10_cmap_.xml
# Written curr/mmTN_parmap10_.xml
# Written curr/mmTN_parmap10_cmap_.xml
# Written curr/mappy_par15_.xml
# Written curr/mappy_par15_cmap_.xml
# Written curr/mappy_naive15_.xml
# Written curr/mappy_naive15_cmap_.xml
# Written curr/mappy_parreduce15_.xml
# Written curr/mappy_parreduce15_cmap_.xml
# Written curr/mappy_parmap15_.xml
# Written curr/mappy_parmap15_cmap_.xml
# Written curr/userfun_par15_.xml
# Written curr/userfun_par15_cmap_.xml
# Written curr/userfun_naive15_.xml
# Written curr/userfun_naive15_cmap_.xml
# Written curr/userfun_parreduce15_.xml
# Written curr/userfun_parreduce15_cmap_.xml
# Written curr/userfun_parmap15_.xml
# Written curr/userfun_parmap15_cmap_.xml
# Written curr/gemvN_par15_.xml
# Written curr/gemvN_par15_cmap_.xml
# Written curr/gemvN_naive15_.xml
# Written curr/gemvN_naive15_cmap_.xml
# Written curr/gemvN_parreduce15_.xml
# Written curr/gemvN_parreduce15_cmap_.xml
# Written curr/gemvN_parmap15_.xml
# Written curr/gemvN_parmap15_cmap_.xml
# Written curr/mydotsmol_par15_.xml
# Written curr/mydotsmol_par15_cmap_.xml
# Written curr/mydotsmol_naive15_.xml
# Written curr/mydotsmol_naive15_cmap_.xml
# Written curr/mydotsmol_parreduce15_.xml
# Written curr/mydotsmol_parreduce15_cmap_.xml
# Written curr/mydotsmol_parmap15_.xml
# Written curr/mydotsmol_parmap15_cmap_.xml
# Written curr/dot_par15_.xml
# Written curr/dot_par15_cmap_.xml
# Written curr/dot_naive15_.xml
# Written curr/dot_naive15_cmap_.xml
# Written curr/dot_parreduce15_.xml
# Written curr/dot_parreduce15_cmap_.xml
# Written curr/dot_parmap15_.xml
# Written curr/dot_parmap15_cmap_.xml
# Written curr/nbody_par15_.xml
# Written curr/nbody_par15_cmap_.xml
# Written curr/nbody_naive15_.xml
# Written curr/nbody_naive15_cmap_.xml
# Written curr/nbody_parreduce15_.xml
# Written curr/nbody_parreduce15_cmap_.xml
# Written curr/nbody_parmap15_.xml
# Written curr/nbody_parmap15_cmap_.xml
# Written curr/gemvT_par15_.xml
# Written curr/gemvT_par15_cmap_.xml
# Written curr/gemvT_naive15_.xml
# Written curr/gemvT_naive15_cmap_.xml
# Written curr/gemvT_parreduce15_.xml
# Written curr/gemvT_parreduce15_cmap_.xml
# Written curr/gemvT_parmap15_.xml
# Written curr/gemvT_parmap15_cmap_.xml
# Written curr/mriqComputeQ_par15_.xml
# Written curr/mriqComputeQ_par15_cmap_.xml
# Written curr/mriqComputeQ_naive15_.xml
# Written curr/mriqComputeQ_naive15_cmap_.xml
# Written curr/mriqComputeQ_parreduce15_.xml
# Written curr/mriqComputeQ_parreduce15_cmap_.xml
# Written curr/mriqComputeQ_parmap15_.xml
# Written curr/mriqComputeQ_parmap15_cmap_.xml
# Written curr/mandelbrot_par15_.xml
# Written curr/mandelbrot_par15_cmap_.xml
# Written curr/mandelbrot_naive15_.xml
# Written curr/mandelbrot_naive15_cmap_.xml
# Written curr/mandelbrot_parreduce15_.xml
# Written curr/mandelbrot_parreduce15_cmap_.xml
# Written curr/mandelbrot_parmap15_.xml
# Written curr/mandelbrot_parmap15_cmap_.xml
# Written curr/addlisttoarray_par15_.xml
# Written curr/addlisttoarray_par15_cmap_.xml
# Written curr/addlisttoarray_naive15_.xml
# Written curr/addlisttoarray_naive15_cmap_.xml
# Written curr/addlisttoarray_parreduce15_.xml
# Written curr/addlisttoarray_parreduce15_cmap_.xml
# Written curr/addlisttoarray_parmap15_.xml
# Written curr/addlisttoarray_parmap15_cmap_.xml
# Written curr/mydot_par15_.xml
# Written curr/mydot_par15_cmap_.xml
# Written curr/mydot_naive15_.xml
# Written curr/mydot_naive15_cmap_.xml
# Written curr/mydot_parreduce15_.xml
# Written curr/mydot_parreduce15_cmap_.xml
# Written curr/mydot_parmap15_.xml
# Written curr/mydot_parmap15_cmap_.xml
# Written curr/blackScholes_par15_.xml
# Written curr/blackScholes_par15_cmap_.xml
# Written curr/blackScholes_naive15_.xml
# Written curr/blackScholes_naive15_cmap_.xml
# Written curr/blackScholes_parreduce15_.xml
# Written curr/blackScholes_parreduce15_cmap_.xml
# Written curr/blackScholes_parmap15_.xml
# Written curr/blackScholes_parmap15_cmap_.xml
# Written curr/mriqPhiMag_par15_.xml
# Written curr/mriqPhiMag_par15_cmap_.xml
# Written curr/mriqPhiMag_naive15_.xml
# Written curr/mriqPhiMag_naive15_cmap_.xml
# Written curr/mriqPhiMag_parreduce15_.xml
# Written curr/mriqPhiMag_parreduce15_cmap_.xml
# Written curr/mriqPhiMag_parmap15_.xml
# Written curr/mriqPhiMag_parmap15_cmap_.xml
# Written curr/asum_par15_.xml
# Written curr/asum_par15_cmap_.xml
# Written curr/asum_naive15_.xml
# Written curr/asum_naive15_cmap_.xml
# Written curr/asum_parreduce15_.xml
# Written curr/asum_parreduce15_cmap_.xml
# Written curr/asum_parmap15_.xml
# Written curr/asum_parmap15_cmap_.xml
# Written curr/mv_par15_.xml
# Written curr/mv_par15_cmap_.xml
# Written curr/mv_naive15_.xml
# Written curr/mv_naive15_cmap_.xml
# Written curr/mv_parreduce15_.xml
# Written curr/mv_parreduce15_cmap_.xml
# Written curr/mv_parmap15_.xml
# Written curr/mv_parmap15_cmap_.xml
# Written curr/nearestNeighbour_par15_.xml
# Written curr/nearestNeighbour_par15_cmap_.xml
# Written curr/nearestNeighbour_naive15_.xml
# Written curr/nearestNeighbour_naive15_cmap_.xml
# Written curr/nearestNeighbour_parreduce15_.xml
# Written curr/nearestNeighbour_parreduce15_cmap_.xml
# Written curr/nearestNeighbour_parmap15_.xml
# Written curr/nearestNeighbour_parmap15_cmap_.xml
# Written curr/scal_par15_.xml
# Written curr/scal_par15_cmap_.xml
# Written curr/scal_naive15_.xml
# Written curr/scal_naive15_cmap_.xml
# Written curr/scal_parreduce15_.xml
# Written curr/scal_parreduce15_cmap_.xml
# Written curr/scal_parmap15_.xml
# Written curr/scal_parmap15_cmap_.xml
# Written curr/mvAsMM_par15_.xml
# Written curr/mvAsMM_par15_cmap_.xml
# Written curr/mvAsMM_naive15_.xml
# Written curr/mvAsMM_naive15_cmap_.xml
# Written curr/mvAsMM_parreduce15_.xml
# Written curr/mvAsMM_parreduce15_cmap_.xml
# Written curr/mvAsMM_parmap15_.xml
# Written curr/mvAsMM_parmap15_cmap_.xml
# Written curr/mmTN_par15_.xml
# Written curr/mmTN_par15_cmap_.xml
# Written curr/mmTN_naive15_.xml
# Written curr/mmTN_naive15_cmap_.xml
# Written curr/mmTN_parreduce15_.xml
# Written curr/mmTN_parreduce15_cmap_.xml
# Written curr/mmTN_parmap15_.xml
# Written curr/mmTN_parmap15_cmap_.xml
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-9162570a76c0> in <module>
#      16     nbase =  'curr/'+csdf[0]+"_"+csdf[1]
#      17     n1 =nbase+'_.xml'
# ---> 18     write_csdf(csdf[2]['graph'], n1)
#      19     print("Written",n1)
#      20     smushed = compose_maps(csdf[2]['graph'])
#
# KeyError: 'graph'

# %%
for csdf in ddcsdfs:
    nbase =  'curr/'+csdf[0]+"_"+csdf[1]
    n2 = nbase+'_cmap_.xml'
    n1 =nbase+'_.xml'
    if n1 not in names and n2 not in names and 'mmTN' in nbase:
        print(n1, n2)
        g = csdf[2] if 'dz' in csdf[1] else csdf[2]['graph']
        write_csdf(g, n1)
        print("Written",n1)
        smushed = compose_maps(g)
        write_csdf(smushed, n2)
        print("Written",n2)
        names += [n1,n2]
# Out:
# curr/mmTN_par50_.xml curr/mmTN_par50_cmap_.xml
# Written curr/mmTN_par50_.xml

# %%
names
# Out:
# ['curr/mappy_par3_.xml',
#  'curr/mappy_par3_cmap_.xml',
#  'curr/mappy_naive3_.xml',
#  'curr/mappy_naive3_cmap_.xml',
#  'curr/mappy_parreduce3_.xml',
#  'curr/mappy_parreduce3_cmap_.xml',
#  'curr/mappy_parmap3_.xml',
#  'curr/mappy_parmap3_cmap_.xml',
#  'curr/userfun_par3_.xml',
#  'curr/userfun_par3_cmap_.xml',
#  'curr/userfun_naive3_.xml',
#  'curr/userfun_naive3_cmap_.xml',
#  'curr/userfun_parreduce3_.xml',
#  'curr/userfun_parreduce3_cmap_.xml',
#  'curr/userfun_parmap3_.xml',
#  'curr/userfun_parmap3_cmap_.xml',
#  'curr/gemvN_par3_.xml',
#  'curr/gemvN_par3_cmap_.xml',
#  'curr/gemvN_naive3_.xml',
#  'curr/gemvN_naive3_cmap_.xml',
#  'curr/gemvN_parreduce3_.xml',
#  'curr/gemvN_parreduce3_cmap_.xml',
#  'curr/gemvN_parmap3_.xml',
#  'curr/gemvN_parmap3_cmap_.xml',
#  'curr/mydotsmol_par3_.xml',
#  'curr/mydotsmol_par3_cmap_.xml',
#  'curr/mydotsmol_naive3_.xml',
#  'curr/mydotsmol_naive3_cmap_.xml',
#  'curr/mydotsmol_parreduce3_.xml',
#  'curr/mydotsmol_parreduce3_cmap_.xml',
#  'curr/mydotsmol_parmap3_.xml',
#  'curr/mydotsmol_parmap3_cmap_.xml',
#  'curr/dot_par3_.xml',
#  'curr/dot_par3_cmap_.xml',
#  'curr/dot_naive3_.xml',
#  'curr/dot_naive3_cmap_.xml',
#  'curr/dot_parreduce3_.xml',
#  'curr/dot_parreduce3_cmap_.xml',
#  'curr/dot_parmap3_.xml',
#  'curr/dot_parmap3_cmap_.xml',
#  'curr/nbody_par3_.xml',
#  'curr/nbody_par3_cmap_.xml',
#  'curr/nbody_naive3_.xml',
#  'curr/nbody_naive3_cmap_.xml',
#  'curr/nbody_parreduce3_.xml',
#  'curr/nbody_parreduce3_cmap_.xml',
#  'curr/nbody_parmap3_.xml',
#  'curr/nbody_parmap3_cmap_.xml',
#  'curr/gemvT_par3_.xml',
#  'curr/gemvT_par3_cmap_.xml',
#  'curr/gemvT_naive3_.xml',
#  'curr/gemvT_naive3_cmap_.xml',
#  'curr/gemvT_parreduce3_.xml',
#  'curr/gemvT_parreduce3_cmap_.xml',
#  'curr/gemvT_parmap3_.xml',
#  'curr/gemvT_parmap3_cmap_.xml',
#  'curr/mriqComputeQ_par3_.xml',
#  'curr/mriqComputeQ_par3_cmap_.xml',
#  'curr/mriqComputeQ_naive3_.xml',
#  'curr/mriqComputeQ_naive3_cmap_.xml',
#  'curr/mriqComputeQ_parreduce3_.xml',
#  'curr/mriqComputeQ_parreduce3_cmap_.xml',
#  'curr/mriqComputeQ_parmap3_.xml',
#  'curr/mriqComputeQ_parmap3_cmap_.xml',
#  'curr/mandelbrot_par3_.xml',
#  'curr/mandelbrot_par3_cmap_.xml',
#  'curr/mandelbrot_naive3_.xml',
#  'curr/mandelbrot_naive3_cmap_.xml',
#  'curr/mandelbrot_parreduce3_.xml',
#  'curr/mandelbrot_parreduce3_cmap_.xml',
#  'curr/mandelbrot_parmap3_.xml',
#  'curr/mandelbrot_parmap3_cmap_.xml',
#  'curr/addlisttoarray_par3_.xml',
#  'curr/addlisttoarray_par3_cmap_.xml',
#  'curr/addlisttoarray_naive3_.xml',
#  'curr/addlisttoarray_naive3_cmap_.xml',
#  'curr/addlisttoarray_parreduce3_.xml',
#  'curr/addlisttoarray_parreduce3_cmap_.xml',
#  'curr/addlisttoarray_parmap3_.xml',
#  'curr/addlisttoarray_parmap3_cmap_.xml',
#  'curr/mydot_par3_.xml',
#  'curr/mydot_par3_cmap_.xml',
#  'curr/mydot_naive3_.xml',
#  'curr/mydot_naive3_cmap_.xml',
#  'curr/mydot_parreduce3_.xml',
#  'curr/mydot_parreduce3_cmap_.xml',
#  'curr/mydot_parmap3_.xml',
#  'curr/mydot_parmap3_cmap_.xml',
#  'curr/blackScholes_par3_.xml',
#  'curr/blackScholes_par3_cmap_.xml',
#  'curr/blackScholes_naive3_.xml',
#  'curr/blackScholes_naive3_cmap_.xml',
#  'curr/blackScholes_parreduce3_.xml',
#  'curr/blackScholes_parreduce3_cmap_.xml',
#  'curr/blackScholes_parmap3_.xml',
#  'curr/blackScholes_parmap3_cmap_.xml',
#  'curr/mriqPhiMag_par3_.xml',
#  'curr/mriqPhiMag_par3_cmap_.xml',
#  'curr/mriqPhiMag_naive3_.xml',
#  'curr/mriqPhiMag_naive3_cmap_.xml',
#  'curr/mriqPhiMag_parreduce3_.xml',
#  'curr/mriqPhiMag_parreduce3_cmap_.xml',
#  'curr/mriqPhiMag_parmap3_.xml',
#  'curr/mriqPhiMag_parmap3_cmap_.xml',
#  'curr/asum_par3_.xml',
#  'curr/asum_par3_cmap_.xml',
#  'curr/asum_naive3_.xml',
#  'curr/asum_naive3_cmap_.xml',
#  'curr/asum_parreduce3_.xml',
#  'curr/asum_parreduce3_cmap_.xml',
#  'curr/asum_parmap3_.xml',
#  'curr/asum_parmap3_cmap_.xml',
#  'curr/mv_par3_.xml',
#  'curr/mv_par3_cmap_.xml',
#  'curr/mv_naive3_.xml',
#  'curr/mv_naive3_cmap_.xml',
#  'curr/mv_parreduce3_.xml',
#  'curr/mv_parreduce3_cmap_.xml',
#  'curr/mv_parmap3_.xml',
#  'curr/mv_parmap3_cmap_.xml',
#  'curr/nearestNeighbour_par3_.xml',
#  'curr/nearestNeighbour_par3_cmap_.xml',
#  'curr/nearestNeighbour_naive3_.xml',
#  'curr/nearestNeighbour_naive3_cmap_.xml',
#  'curr/nearestNeighbour_parreduce3_.xml',
#  'curr/nearestNeighbour_parreduce3_cmap_.xml',
#  'curr/nearestNeighbour_parmap3_.xml',
#  'curr/nearestNeighbour_parmap3_cmap_.xml',
#  'curr/scal_par3_.xml',
#  'curr/scal_par3_cmap_.xml',
#  'curr/scal_naive3_.xml',
#  'curr/scal_naive3_cmap_.xml',
#  'curr/scal_parreduce3_.xml',
#  'curr/scal_parreduce3_cmap_.xml',
#  'curr/scal_parmap3_.xml',
#  'curr/scal_parmap3_cmap_.xml',
#  'curr/mvAsMM_par3_.xml',
#  'curr/mvAsMM_par3_cmap_.xml',
#  'curr/mvAsMM_naive3_.xml',
#  'curr/mvAsMM_naive3_cmap_.xml',
#  'curr/mvAsMM_parreduce3_.xml',
#  'curr/mvAsMM_parreduce3_cmap_.xml',
#  'curr/mvAsMM_parmap3_.xml',
#  'curr/mvAsMM_parmap3_cmap_.xml',
#  'curr/mmTN_par3_.xml',
#  'curr/mmTN_par3_cmap_.xml',
#  'curr/mmTN_naive3_.xml',
#  'curr/mmTN_naive3_cmap_.xml',
#  'curr/mmTN_parreduce3_.xml',
#  'curr/mmTN_parreduce3_cmap_.xml',
#  'curr/mmTN_parmap3_.xml',
#  'curr/mmTN_parmap3_cmap_.xml',
#  'curr/mappy_par5_.xml',
#  'curr/mappy_par5_cmap_.xml',
#  'curr/mappy_naive5_.xml',
#  'curr/mappy_naive5_cmap_.xml',
#  'curr/mappy_parreduce5_.xml',
#  'curr/mappy_parreduce5_cmap_.xml',
#  'curr/mappy_parmap5_.xml',
#  'curr/mappy_parmap5_cmap_.xml',
#  'curr/userfun_par5_.xml',
#  'curr/userfun_par5_cmap_.xml',
#  'curr/userfun_naive5_.xml',
#  'curr/userfun_naive5_cmap_.xml',
#  'curr/userfun_parreduce5_.xml',
#  'curr/userfun_parreduce5_cmap_.xml',
#  'curr/userfun_parmap5_.xml',
#  'curr/userfun_parmap5_cmap_.xml',
#  'curr/gemvN_par5_.xml',
#  'curr/gemvN_par5_cmap_.xml',
#  'curr/gemvN_naive5_.xml',
#  'curr/gemvN_naive5_cmap_.xml',
#  'curr/gemvN_parreduce5_.xml',
#  'curr/gemvN_parreduce5_cmap_.xml',
#  'curr/gemvN_parmap5_.xml',
#  'curr/gemvN_parmap5_cmap_.xml',
#  'curr/mydotsmol_par5_.xml',
#  'curr/mydotsmol_par5_cmap_.xml',
#  'curr/mydotsmol_naive5_.xml',
#  'curr/mydotsmol_naive5_cmap_.xml',
#  'curr/mydotsmol_parreduce5_.xml',
#  'curr/mydotsmol_parreduce5_cmap_.xml',
#  'curr/mydotsmol_parmap5_.xml',
#  'curr/mydotsmol_parmap5_cmap_.xml',
#  'curr/dot_par5_.xml',
#  'curr/dot_par5_cmap_.xml',
#  'curr/dot_naive5_.xml',
#  'curr/dot_naive5_cmap_.xml',
#  'curr/dot_parreduce5_.xml',
#  'curr/dot_parreduce5_cmap_.xml',
#  'curr/dot_parmap5_.xml',
#  'curr/dot_parmap5_cmap_.xml',
#  'curr/nbody_par5_.xml',
#  'curr/nbody_par5_cmap_.xml',
#  'curr/nbody_naive5_.xml',
#  'curr/nbody_naive5_cmap_.xml',
#  'curr/nbody_parreduce5_.xml',
#  'curr/nbody_parreduce5_cmap_.xml',
#  'curr/nbody_parmap5_.xml',
#  'curr/nbody_parmap5_cmap_.xml',
#  'curr/gemvT_par5_.xml',
#  'curr/gemvT_par5_cmap_.xml',
#  'curr/gemvT_naive5_.xml',
#  'curr/gemvT_naive5_cmap_.xml',
#  'curr/gemvT_parreduce5_.xml',
#  'curr/gemvT_parreduce5_cmap_.xml',
#  'curr/gemvT_parmap5_.xml',
#  'curr/gemvT_parmap5_cmap_.xml',
#  'curr/mriqComputeQ_par5_.xml',
#  'curr/mriqComputeQ_par5_cmap_.xml',
#  'curr/mriqComputeQ_naive5_.xml',
#  'curr/mriqComputeQ_naive5_cmap_.xml',
#  'curr/mriqComputeQ_parreduce5_.xml',
#  'curr/mriqComputeQ_parreduce5_cmap_.xml',
#  'curr/mriqComputeQ_parmap5_.xml',
#  'curr/mriqComputeQ_parmap5_cmap_.xml',
#  'curr/mandelbrot_par5_.xml',
#  'curr/mandelbrot_par5_cmap_.xml',
#  'curr/mandelbrot_naive5_.xml',
#  'curr/mandelbrot_naive5_cmap_.xml',
#  'curr/mandelbrot_parreduce5_.xml',
#  'curr/mandelbrot_parreduce5_cmap_.xml',
#  'curr/mandelbrot_parmap5_.xml',
#  'curr/mandelbrot_parmap5_cmap_.xml',
#  'curr/addlisttoarray_par5_.xml',
#  'curr/addlisttoarray_par5_cmap_.xml',
#  'curr/addlisttoarray_naive5_.xml',
#  'curr/addlisttoarray_naive5_cmap_.xml',
#  'curr/addlisttoarray_parreduce5_.xml',
#  'curr/addlisttoarray_parreduce5_cmap_.xml',
#  'curr/addlisttoarray_parmap5_.xml',
#  'curr/addlisttoarray_parmap5_cmap_.xml',
#  'curr/mydot_par5_.xml',
#  'curr/mydot_par5_cmap_.xml',
#  'curr/mydot_naive5_.xml',
#  'curr/mydot_naive5_cmap_.xml',
#  'curr/mydot_parreduce5_.xml',
#  'curr/mydot_parreduce5_cmap_.xml',
#  'curr/mydot_parmap5_.xml',
#  'curr/mydot_parmap5_cmap_.xml',
#  'curr/blackScholes_par5_.xml',
#  'curr/blackScholes_par5_cmap_.xml',
#  'curr/blackScholes_naive5_.xml',
#  'curr/blackScholes_naive5_cmap_.xml',
#  'curr/blackScholes_parreduce5_.xml',
#  'curr/blackScholes_parreduce5_cmap_.xml',
#  'curr/blackScholes_parmap5_.xml',
#  'curr/blackScholes_parmap5_cmap_.xml',
#  'curr/mriqPhiMag_par5_.xml',
#  'curr/mriqPhiMag_par5_cmap_.xml',
#  'curr/mriqPhiMag_naive5_.xml',
#  'curr/mriqPhiMag_naive5_cmap_.xml',
#  'curr/mriqPhiMag_parreduce5_.xml',
#  'curr/mriqPhiMag_parreduce5_cmap_.xml',
#  'curr/mriqPhiMag_parmap5_.xml',
#  'curr/mriqPhiMag_parmap5_cmap_.xml',
#  'curr/asum_par5_.xml',
#  'curr/asum_par5_cmap_.xml',
#  'curr/asum_naive5_.xml',
#  'curr/asum_naive5_cmap_.xml',
#  'curr/asum_parreduce5_.xml',
#  'curr/asum_parreduce5_cmap_.xml',
#  'curr/asum_parmap5_.xml',
#  'curr/asum_parmap5_cmap_.xml',
#  'curr/mv_par5_.xml',
#  'curr/mv_par5_cmap_.xml',
#  'curr/mv_naive5_.xml',
#  'curr/mv_naive5_cmap_.xml',
#  'curr/mv_parreduce5_.xml',
#  'curr/mv_parreduce5_cmap_.xml',
#  'curr/mv_parmap5_.xml',
#  'curr/mv_parmap5_cmap_.xml',
#  'curr/nearestNeighbour_par5_.xml',
#  'curr/nearestNeighbour_par5_cmap_.xml',
#  'curr/nearestNeighbour_naive5_.xml',
#  'curr/nearestNeighbour_naive5_cmap_.xml',
#  'curr/nearestNeighbour_parreduce5_.xml',
#  'curr/nearestNeighbour_parreduce5_cmap_.xml',
#  'curr/nearestNeighbour_parmap5_.xml',
#  'curr/nearestNeighbour_parmap5_cmap_.xml',
#  'curr/scal_par5_.xml',
#  'curr/scal_par5_cmap_.xml',
#  'curr/scal_naive5_.xml',
#  'curr/scal_naive5_cmap_.xml',
#  'curr/scal_parreduce5_.xml',
#  'curr/scal_parreduce5_cmap_.xml',
#  'curr/scal_parmap5_.xml',
#  'curr/scal_parmap5_cmap_.xml',
#  'curr/mvAsMM_par5_.xml',
#  'curr/mvAsMM_par5_cmap_.xml',
#  'curr/mvAsMM_naive5_.xml',
#  'curr/mvAsMM_naive5_cmap_.xml',
#  'curr/mvAsMM_parreduce5_.xml',
#  'curr/mvAsMM_parreduce5_cmap_.xml',
#  'curr/mvAsMM_parmap5_.xml',
#  'curr/mvAsMM_parmap5_cmap_.xml',
#  'curr/mmTN_par5_.xml',
#  'curr/mmTN_par5_cmap_.xml',
#  'curr/mmTN_naive5_.xml',
#  'curr/mmTN_naive5_cmap_.xml',
#  'curr/mmTN_parreduce5_.xml',
#  'curr/mmTN_parreduce5_cmap_.xml',
#  'curr/mmTN_parmap5_.xml',
#  'curr/mmTN_parmap5_cmap_.xml',
#  'curr/mappy_par7_.xml',
#  'curr/mappy_par7_cmap_.xml',
#  'curr/mappy_naive7_.xml',
#  'curr/mappy_naive7_cmap_.xml',
#  'curr/mappy_parreduce7_.xml',
#  'curr/mappy_parreduce7_cmap_.xml',
#  'curr/mappy_parmap7_.xml',
#  'curr/mappy_parmap7_cmap_.xml',
#  'curr/userfun_par7_.xml',
#  'curr/userfun_par7_cmap_.xml',
#  'curr/userfun_naive7_.xml',
#  'curr/userfun_naive7_cmap_.xml',
#  'curr/userfun_parreduce7_.xml',
#  'curr/userfun_parreduce7_cmap_.xml',
#  'curr/userfun_parmap7_.xml',
#  'curr/userfun_parmap7_cmap_.xml',
#  'curr/gemvN_par7_.xml',
#  'curr/gemvN_par7_cmap_.xml',
#  'curr/gemvN_naive7_.xml',
#  'curr/gemvN_naive7_cmap_.xml',
#  'curr/gemvN_parreduce7_.xml',
#  'curr/gemvN_parreduce7_cmap_.xml',
#  'curr/gemvN_parmap7_.xml',
#  'curr/gemvN_parmap7_cmap_.xml',
#  'curr/mydotsmol_par7_.xml',
#  'curr/mydotsmol_par7_cmap_.xml',
#  'curr/mydotsmol_naive7_.xml',
#  'curr/mydotsmol_naive7_cmap_.xml',
#  'curr/mydotsmol_parreduce7_.xml',
#  'curr/mydotsmol_parreduce7_cmap_.xml',
#  'curr/mydotsmol_parmap7_.xml',
#  'curr/mydotsmol_parmap7_cmap_.xml',
#  'curr/dot_par7_.xml',
#  'curr/dot_par7_cmap_.xml',
#  'curr/dot_naive7_.xml',
#  'curr/dot_naive7_cmap_.xml',
#  'curr/dot_parreduce7_.xml',
#  'curr/dot_parreduce7_cmap_.xml',
#  'curr/dot_parmap7_.xml',
#  'curr/dot_parmap7_cmap_.xml',
#  'curr/nbody_par7_.xml',
#  'curr/nbody_par7_cmap_.xml',
#  'curr/nbody_naive7_.xml',
#  'curr/nbody_naive7_cmap_.xml',
#  'curr/nbody_parreduce7_.xml',
#  'curr/nbody_parreduce7_cmap_.xml',
#  'curr/nbody_parmap7_.xml',
#  'curr/nbody_parmap7_cmap_.xml',
#  'curr/gemvT_par7_.xml',
#  'curr/gemvT_par7_cmap_.xml',
#  'curr/gemvT_naive7_.xml',
#  'curr/gemvT_naive7_cmap_.xml',
#  'curr/gemvT_parreduce7_.xml',
#  'curr/gemvT_parreduce7_cmap_.xml',
#  'curr/gemvT_parmap7_.xml',
#  'curr/gemvT_parmap7_cmap_.xml',
#  'curr/mriqComputeQ_par7_.xml',
#  'curr/mriqComputeQ_par7_cmap_.xml',
#  'curr/mriqComputeQ_naive7_.xml',
#  'curr/mriqComputeQ_naive7_cmap_.xml',
#  'curr/mriqComputeQ_parreduce7_.xml',
#  'curr/mriqComputeQ_parreduce7_cmap_.xml',
#  'curr/mriqComputeQ_parmap7_.xml',
#  'curr/mriqComputeQ_parmap7_cmap_.xml',
#  'curr/mandelbrot_par7_.xml',
#  'curr/mandelbrot_par7_cmap_.xml',
#  'curr/mandelbrot_naive7_.xml',
#  'curr/mandelbrot_naive7_cmap_.xml',
#  'curr/mandelbrot_parreduce7_.xml',
#  'curr/mandelbrot_parreduce7_cmap_.xml',
#  'curr/mandelbrot_parmap7_.xml',
#  'curr/mandelbrot_parmap7_cmap_.xml',
#  'curr/addlisttoarray_par7_.xml',
#  'curr/addlisttoarray_par7_cmap_.xml',
#  'curr/addlisttoarray_naive7_.xml',
#  'curr/addlisttoarray_naive7_cmap_.xml',
#  'curr/addlisttoarray_parreduce7_.xml',
#  'curr/addlisttoarray_parreduce7_cmap_.xml',
#  'curr/addlisttoarray_parmap7_.xml',
#  'curr/addlisttoarray_parmap7_cmap_.xml',
#  'curr/mydot_par7_.xml',
#  'curr/mydot_par7_cmap_.xml',
#  'curr/mydot_naive7_.xml',
#  'curr/mydot_naive7_cmap_.xml',
#  'curr/mydot_parreduce7_.xml',
#  'curr/mydot_parreduce7_cmap_.xml',
#  'curr/mydot_parmap7_.xml',
#  'curr/mydot_parmap7_cmap_.xml',
#  'curr/blackScholes_par7_.xml',
#  'curr/blackScholes_par7_cmap_.xml',
#  'curr/blackScholes_naive7_.xml',
#  'curr/blackScholes_naive7_cmap_.xml',
#  'curr/blackScholes_parreduce7_.xml',
#  'curr/blackScholes_parreduce7_cmap_.xml',
#  'curr/blackScholes_parmap7_.xml',
#  'curr/blackScholes_parmap7_cmap_.xml',
#  'curr/mriqPhiMag_par7_.xml',
#  'curr/mriqPhiMag_par7_cmap_.xml',
#  'curr/mriqPhiMag_naive7_.xml',
#  'curr/mriqPhiMag_naive7_cmap_.xml',
#  'curr/mriqPhiMag_parreduce7_.xml',
#  'curr/mriqPhiMag_parreduce7_cmap_.xml',
#  'curr/mriqPhiMag_parmap7_.xml',
#  'curr/mriqPhiMag_parmap7_cmap_.xml',
#  'curr/asum_par7_.xml',
#  'curr/asum_par7_cmap_.xml',
#  'curr/asum_naive7_.xml',
#  'curr/asum_naive7_cmap_.xml',
#  'curr/asum_parreduce7_.xml',
#  'curr/asum_parreduce7_cmap_.xml',
#  'curr/asum_parmap7_.xml',
#  'curr/asum_parmap7_cmap_.xml',
#  'curr/mv_par7_.xml',
#  'curr/mv_par7_cmap_.xml',
#  'curr/mv_naive7_.xml',
#  'curr/mv_naive7_cmap_.xml',
#  'curr/mv_parreduce7_.xml',
#  'curr/mv_parreduce7_cmap_.xml',
#  'curr/mv_parmap7_.xml',
#  'curr/mv_parmap7_cmap_.xml',
#  'curr/nearestNeighbour_par7_.xml',
#  'curr/nearestNeighbour_par7_cmap_.xml',
#  'curr/nearestNeighbour_naive7_.xml',
#  'curr/nearestNeighbour_naive7_cmap_.xml',
#  'curr/nearestNeighbour_parreduce7_.xml',
#  'curr/nearestNeighbour_parreduce7_cmap_.xml',
#  'curr/nearestNeighbour_parmap7_.xml',
#  'curr/nearestNeighbour_parmap7_cmap_.xml',
#  'curr/scal_par7_.xml',
#  'curr/scal_par7_cmap_.xml',
#  'curr/scal_naive7_.xml',
#  'curr/scal_naive7_cmap_.xml',
#  'curr/scal_parreduce7_.xml',
#  'curr/scal_parreduce7_cmap_.xml',
#  'curr/scal_parmap7_.xml',
#  'curr/scal_parmap7_cmap_.xml',
#  'curr/mvAsMM_par7_.xml',
#  'curr/mvAsMM_par7_cmap_.xml',
#  'curr/mvAsMM_naive7_.xml',
#  'curr/mvAsMM_naive7_cmap_.xml',
#  'curr/mvAsMM_parreduce7_.xml',
#  'curr/mvAsMM_parreduce7_cmap_.xml',
#  'curr/mvAsMM_parmap7_.xml',
#  'curr/mvAsMM_parmap7_cmap_.xml',
#  'curr/mmTN_par7_.xml',
#  'curr/mmTN_par7_cmap_.xml',
#  'curr/mmTN_naive7_.xml',
#  'curr/mmTN_naive7_cmap_.xml',
#  'curr/mmTN_parreduce7_.xml',
#  'curr/mmTN_parreduce7_cmap_.xml',
#  'curr/mmTN_parmap7_.xml',
#  'curr/mmTN_parmap7_cmap_.xml',
#  'curr/mappy_par10_.xml',
#  'curr/mappy_par10_cmap_.xml',
#  'curr/mappy_naive10_.xml',
#  'curr/mappy_naive10_cmap_.xml',
#  'curr/mappy_parreduce10_.xml',
#  'curr/mappy_parreduce10_cmap_.xml',
#  'curr/mappy_parmap10_.xml',
#  'curr/mappy_parmap10_cmap_.xml',
#  'curr/userfun_par10_.xml',
#  'curr/userfun_par10_cmap_.xml',
#  'curr/userfun_naive10_.xml',
#  'curr/userfun_naive10_cmap_.xml',
#  'curr/userfun_parreduce10_.xml',
#  'curr/userfun_parreduce10_cmap_.xml',
#  'curr/userfun_parmap10_.xml',
#  'curr/userfun_parmap10_cmap_.xml',
#  'curr/gemvN_par10_.xml',
#  'curr/gemvN_par10_cmap_.xml',
#  'curr/gemvN_naive10_.xml',
#  'curr/gemvN_naive10_cmap_.xml',
#  'curr/gemvN_parreduce10_.xml',
#  'curr/gemvN_parreduce10_cmap_.xml',
#  'curr/gemvN_parmap10_.xml',
#  'curr/gemvN_parmap10_cmap_.xml',
#  'curr/mydotsmol_par10_.xml',
#  'curr/mydotsmol_par10_cmap_.xml',
#  'curr/mydotsmol_naive10_.xml',
#  'curr/mydotsmol_naive10_cmap_.xml',
#  'curr/mydotsmol_parreduce10_.xml',
#  'curr/mydotsmol_parreduce10_cmap_.xml',
#  'curr/mydotsmol_parmap10_.xml',
#  'curr/mydotsmol_parmap10_cmap_.xml',
#  'curr/dot_par10_.xml',
#  'curr/dot_par10_cmap_.xml',
#  'curr/dot_naive10_.xml',
#  'curr/dot_naive10_cmap_.xml',
#  'curr/dot_parreduce10_.xml',
#  'curr/dot_parreduce10_cmap_.xml',
#  'curr/dot_parmap10_.xml',
#  'curr/dot_parmap10_cmap_.xml',
#  'curr/nbody_par10_.xml',
#  'curr/nbody_par10_cmap_.xml',
#  'curr/nbody_naive10_.xml',
#  'curr/nbody_naive10_cmap_.xml',
#  'curr/nbody_parreduce10_.xml',
#  'curr/nbody_parreduce10_cmap_.xml',
#  'curr/nbody_parmap10_.xml',
#  'curr/nbody_parmap10_cmap_.xml',
#  'curr/gemvT_par10_.xml',
#  'curr/gemvT_par10_cmap_.xml',
#  'curr/gemvT_naive10_.xml',
#  'curr/gemvT_naive10_cmap_.xml',
#  'curr/gemvT_parreduce10_.xml',
#  'curr/gemvT_parreduce10_cmap_.xml',
#  'curr/gemvT_parmap10_.xml',
#  'curr/gemvT_parmap10_cmap_.xml',
#  'curr/mriqComputeQ_par10_.xml',
#  'curr/mriqComputeQ_par10_cmap_.xml',
#  'curr/mriqComputeQ_naive10_.xml',
#  'curr/mriqComputeQ_naive10_cmap_.xml',
#  'curr/mriqComputeQ_parreduce10_.xml',
#  'curr/mriqComputeQ_parreduce10_cmap_.xml',
#  'curr/mriqComputeQ_parmap10_.xml',
#  'curr/mriqComputeQ_parmap10_cmap_.xml',
#  'curr/mandelbrot_par10_.xml',
#  'curr/mandelbrot_par10_cmap_.xml',
#  'curr/mandelbrot_naive10_.xml',
#  'curr/mandelbrot_naive10_cmap_.xml',
#  'curr/mandelbrot_parreduce10_.xml',
#  'curr/mandelbrot_parreduce10_cmap_.xml',
#  'curr/mandelbrot_parmap10_.xml',
#  'curr/mandelbrot_parmap10_cmap_.xml',
#  'curr/addlisttoarray_par10_.xml',
#  'curr/addlisttoarray_par10_cmap_.xml',
#  'curr/addlisttoarray_naive10_.xml',
#  'curr/addlisttoarray_naive10_cmap_.xml',
#  'curr/addlisttoarray_parreduce10_.xml',
#  'curr/addlisttoarray_parreduce10_cmap_.xml',
#  'curr/addlisttoarray_parmap10_.xml',
#  'curr/addlisttoarray_parmap10_cmap_.xml',
#  'curr/mydot_par10_.xml',
#  'curr/mydot_par10_cmap_.xml',
#  'curr/mydot_naive10_.xml',
#  'curr/mydot_naive10_cmap_.xml',
#  'curr/mydot_parreduce10_.xml',
#  'curr/mydot_parreduce10_cmap_.xml',
#  'curr/mydot_parmap10_.xml',
#  'curr/mydot_parmap10_cmap_.xml',
#  'curr/blackScholes_par10_.xml',
#  'curr/blackScholes_par10_cmap_.xml',
#  'curr/blackScholes_naive10_.xml',
#  'curr/blackScholes_naive10_cmap_.xml',
#  'curr/blackScholes_parreduce10_.xml',
#  'curr/blackScholes_parreduce10_cmap_.xml',
#  'curr/blackScholes_parmap10_.xml',
#  'curr/blackScholes_parmap10_cmap_.xml',
#  'curr/mriqPhiMag_par10_.xml',
#  'curr/mriqPhiMag_par10_cmap_.xml',
#  'curr/mriqPhiMag_naive10_.xml',
#  'curr/mriqPhiMag_naive10_cmap_.xml',
#  'curr/mriqPhiMag_parreduce10_.xml',
#  'curr/mriqPhiMag_parreduce10_cmap_.xml',
#  'curr/mriqPhiMag_parmap10_.xml',
#  'curr/mriqPhiMag_parmap10_cmap_.xml',
#  'curr/asum_par10_.xml',
#  'curr/asum_par10_cmap_.xml',
#  'curr/asum_naive10_.xml',
#  'curr/asum_naive10_cmap_.xml',
#  'curr/asum_parreduce10_.xml',
#  'curr/asum_parreduce10_cmap_.xml',
#  'curr/asum_parmap10_.xml',
#  'curr/asum_parmap10_cmap_.xml',
#  'curr/mv_par10_.xml',
#  'curr/mv_par10_cmap_.xml',
#  'curr/mv_naive10_.xml',
#  'curr/mv_naive10_cmap_.xml',
#  'curr/mv_parreduce10_.xml',
#  'curr/mv_parreduce10_cmap_.xml',
#  'curr/mv_parmap10_.xml',
#  'curr/mv_parmap10_cmap_.xml',
#  'curr/nearestNeighbour_par10_.xml',
#  'curr/nearestNeighbour_par10_cmap_.xml',
#  'curr/nearestNeighbour_naive10_.xml',
#  'curr/nearestNeighbour_naive10_cmap_.xml',
#  'curr/nearestNeighbour_parreduce10_.xml',
#  'curr/nearestNeighbour_parreduce10_cmap_.xml',
#  'curr/nearestNeighbour_parmap10_.xml',
#  'curr/nearestNeighbour_parmap10_cmap_.xml',
#  'curr/scal_par10_.xml',
#  'curr/scal_par10_cmap_.xml',
#  'curr/scal_naive10_.xml',
#  'curr/scal_naive10_cmap_.xml',
#  'curr/scal_parreduce10_.xml',
#  'curr/scal_parreduce10_cmap_.xml',
#  'curr/scal_parmap10_.xml',
#  'curr/scal_parmap10_cmap_.xml',
#  'curr/mvAsMM_par10_.xml',
#  'curr/mvAsMM_par10_cmap_.xml',
#  'curr/mvAsMM_naive10_.xml',
#  'curr/mvAsMM_naive10_cmap_.xml',
#  'curr/mvAsMM_parreduce10_.xml',
#  'curr/mvAsMM_parreduce10_cmap_.xml',
#  'curr/mvAsMM_parmap10_.xml',
#  'curr/mvAsMM_parmap10_cmap_.xml',
#  'curr/mmTN_par10_.xml',
#  'curr/mmTN_par10_cmap_.xml',
#  'curr/mmTN_naive10_.xml',
#  'curr/mmTN_naive10_cmap_.xml',
#  'curr/mmTN_parreduce10_.xml',
#  'curr/mmTN_parreduce10_cmap_.xml',
#  'curr/mmTN_parmap10_.xml',
#  'curr/mmTN_parmap10_cmap_.xml',
#  'curr/mappy_par15_.xml',
#  'curr/mappy_par15_cmap_.xml',
#  'curr/mappy_naive15_.xml',
#  'curr/mappy_naive15_cmap_.xml',
#  'curr/mappy_parreduce15_.xml',
#  'curr/mappy_parreduce15_cmap_.xml',
#  'curr/mappy_parmap15_.xml',
#  'curr/mappy_parmap15_cmap_.xml',
#  'curr/userfun_par15_.xml',
#  'curr/userfun_par15_cmap_.xml',
#  'curr/userfun_naive15_.xml',
#  'curr/userfun_naive15_cmap_.xml',
#  'curr/userfun_parreduce15_.xml',
#  'curr/userfun_parreduce15_cmap_.xml',
#  'curr/userfun_parmap15_.xml',
#  'curr/userfun_parmap15_cmap_.xml',
#  'curr/gemvN_par15_.xml',
#  'curr/gemvN_par15_cmap_.xml',
#  'curr/gemvN_naive15_.xml',
#  'curr/gemvN_naive15_cmap_.xml',
#  'curr/gemvN_parreduce15_.xml',
#  'curr/gemvN_parreduce15_cmap_.xml',
#  'curr/gemvN_parmap15_.xml',
#  'curr/gemvN_parmap15_cmap_.xml',
#  'curr/mydotsmol_par15_.xml',
#  'curr/mydotsmol_par15_cmap_.xml',
#  'curr/mydotsmol_naive15_.xml',
#  'curr/mydotsmol_naive15_cmap_.xml',
#  'curr/mydotsmol_parreduce15_.xml',
#  'curr/mydotsmol_parreduce15_cmap_.xml',
#  'curr/mydotsmol_parmap15_.xml',
#  'curr/mydotsmol_parmap15_cmap_.xml',
#  'curr/dot_par15_.xml',
#  'curr/dot_par15_cmap_.xml',
#  'curr/dot_naive15_.xml',
#  'curr/dot_naive15_cmap_.xml',
#  'curr/dot_parreduce15_.xml',
#  'curr/dot_parreduce15_cmap_.xml',
#  'curr/dot_parmap15_.xml',
#  'curr/dot_parmap15_cmap_.xml',
#  'curr/nbody_par15_.xml',
#  'curr/nbody_par15_cmap_.xml',
#  'curr/nbody_naive15_.xml',
#  'curr/nbody_naive15_cmap_.xml',
#  'curr/nbody_parreduce15_.xml',
#  'curr/nbody_parreduce15_cmap_.xml',
#  'curr/nbody_parmap15_.xml',
#  'curr/nbody_parmap15_cmap_.xml',
#  'curr/gemvT_par15_.xml',
#  'curr/gemvT_par15_cmap_.xml',
#  'curr/gemvT_naive15_.xml',
#  'curr/gemvT_naive15_cmap_.xml',
#  'curr/gemvT_parreduce15_.xml',
#  'curr/gemvT_parreduce15_cmap_.xml',
#  'curr/gemvT_parmap15_.xml',
#  'curr/gemvT_parmap15_cmap_.xml',
#  'curr/mriqComputeQ_par15_.xml',
#  'curr/mriqComputeQ_par15_cmap_.xml',
#  'curr/mriqComputeQ_naive15_.xml',
#  'curr/mriqComputeQ_naive15_cmap_.xml',
#  'curr/mriqComputeQ_parreduce15_.xml',
#  'curr/mriqComputeQ_parreduce15_cmap_.xml',
#  'curr/mriqComputeQ_parmap15_.xml',
#  'curr/mriqComputeQ_parmap15_cmap_.xml',
#  'curr/mandelbrot_par15_.xml',
#  'curr/mandelbrot_par15_cmap_.xml',
#  'curr/mandelbrot_naive15_.xml',
#  'curr/mandelbrot_naive15_cmap_.xml',
#  'curr/mandelbrot_parreduce15_.xml',
#  'curr/mandelbrot_parreduce15_cmap_.xml',
#  'curr/mandelbrot_parmap15_.xml',
#  'curr/mandelbrot_parmap15_cmap_.xml',
#  'curr/addlisttoarray_par15_.xml',
#  'curr/addlisttoarray_par15_cmap_.xml',
#  'curr/addlisttoarray_naive15_.xml',
#  'curr/addlisttoarray_naive15_cmap_.xml',
#  'curr/addlisttoarray_parreduce15_.xml',
#  'curr/addlisttoarray_parreduce15_cmap_.xml',
#  'curr/addlisttoarray_parmap15_.xml',
#  'curr/addlisttoarray_parmap15_cmap_.xml',
#  'curr/mydot_par15_.xml',
#  'curr/mydot_par15_cmap_.xml',
#  'curr/mydot_naive15_.xml',
#  'curr/mydot_naive15_cmap_.xml',
#  'curr/mydot_parreduce15_.xml',
#  'curr/mydot_parreduce15_cmap_.xml',
#  'curr/mydot_parmap15_.xml',
#  'curr/mydot_parmap15_cmap_.xml',
#  'curr/blackScholes_par15_.xml',
#  'curr/blackScholes_par15_cmap_.xml',
#  'curr/blackScholes_naive15_.xml',
#  'curr/blackScholes_naive15_cmap_.xml',
#  'curr/blackScholes_parreduce15_.xml',
#  'curr/blackScholes_parreduce15_cmap_.xml',
#  'curr/blackScholes_parmap15_.xml',
#  'curr/blackScholes_parmap15_cmap_.xml',
#  'curr/mriqPhiMag_par15_.xml',
#  'curr/mriqPhiMag_par15_cmap_.xml',
#  'curr/mriqPhiMag_naive15_.xml',
#  'curr/mriqPhiMag_naive15_cmap_.xml',
#  'curr/mriqPhiMag_parreduce15_.xml',
#  'curr/mriqPhiMag_parreduce15_cmap_.xml',
#  'curr/mriqPhiMag_parmap15_.xml',
#  'curr/mriqPhiMag_parmap15_cmap_.xml',
#  'curr/asum_par15_.xml',
#  'curr/asum_par15_cmap_.xml',
#  'curr/asum_naive15_.xml',
#  'curr/asum_naive15_cmap_.xml',
#  'curr/asum_parreduce15_.xml',
#  'curr/asum_parreduce15_cmap_.xml',
#  'curr/asum_parmap15_.xml',
#  'curr/asum_parmap15_cmap_.xml',
#  'curr/mv_par15_.xml',
#  'curr/mv_par15_cmap_.xml',
#  'curr/mv_naive15_.xml',
#  'curr/mv_naive15_cmap_.xml',
#  'curr/mv_parreduce15_.xml',
#  'curr/mv_parreduce15_cmap_.xml',
#  'curr/mv_parmap15_.xml',
#  'curr/mv_parmap15_cmap_.xml',
#  'curr/nearestNeighbour_par15_.xml',
#  'curr/nearestNeighbour_par15_cmap_.xml',
#  'curr/nearestNeighbour_naive15_.xml',
#  'curr/nearestNeighbour_naive15_cmap_.xml',
#  'curr/nearestNeighbour_parreduce15_.xml',
#  'curr/nearestNeighbour_parreduce15_cmap_.xml',
#  'curr/nearestNeighbour_parmap15_.xml',
#  'curr/nearestNeighbour_parmap15_cmap_.xml',
#  'curr/scal_par15_.xml',
#  'curr/scal_par15_cmap_.xml',
#  'curr/scal_naive15_.xml',
#  'curr/scal_naive15_cmap_.xml',
#  'curr/scal_parreduce15_.xml',
#  'curr/scal_parreduce15_cmap_.xml',
#  'curr/scal_parmap15_.xml',
#  'curr/scal_parmap15_cmap_.xml',
#  'curr/mvAsMM_par15_.xml',
#  'curr/mvAsMM_par15_cmap_.xml',
#  'curr/mvAsMM_naive15_.xml',
#  'curr/mvAsMM_naive15_cmap_.xml',
#  'curr/mvAsMM_parreduce15_.xml',
#  'curr/mvAsMM_parreduce15_cmap_.xml',
#  'curr/mvAsMM_parmap15_.xml',
#  'curr/mvAsMM_parmap15_cmap_.xml',
#  'curr/mmTN_par15_.xml',
#  'curr/mmTN_par15_cmap_.xml',
#  'curr/mmTN_naive15_.xml',
#  'curr/mmTN_naive15_cmap_.xml',
#  'curr/mmTN_parreduce15_.xml',
#  'curr/mmTN_parreduce15_cmap_.xml',
#  'curr/mmTN_parmap15_.xml',
#  'curr/mmTN_parmap15_cmap_.xml']

# %%
ddcsdfs = [(a[0], a[1], b) for a, b in dict([((x[0], x[1]), x[2]) for x in csdfs]).items()]

# %%
len(csdfs), len(ddcsdfs)
# Out:
# (1436, 1056)

# %%
len([x for x in ddcsdfs if 'dz' in x[1]])
# Out:
# 528

# %%
csdfs[354]
# Out:
# ('mriqPhiMag',
#  'parreduce15',
#  {'sizevars': ['k'],
#   'inputs': [('phiR', 'ArrayTypeWSWC(Float, k)'),
#    ('phiI', 'ArrayTypeWSWC(Float, k)')],
#   'code': '\n  ArrayTypeWSWC(Float, k),\n  ArrayTypeWSWC(Float, k),\n  (phiR, phiI) => Map(\\(x => phiMag(Get(x, 0), Get(x, 1)))) $ Zip(phiR, phiI)\n',
#   'graph': {'nodes': [<__main__.Param at 0x1243a9890>,
#     <__main__.Param at 0x1243a9a50>,
#     <__main__.Zip at 0x1243ad950>,
#     <__main__.Param at 0x1243a9d90>,
#     <__main__.Get at 0x1243ad150>,
#     <__main__.Get at 0x1243ad3d0>,
#     <__main__.UserFun at 0x1243a9e50>,
#     <__main__.Dearray at 0x1243af990>,
#     <__main__.Rearray at 0x1243afa90>],
#    'channels': [<__main__.Channel at 0x1243ad9d0>,
#     <__main__.Channel at 0x1243add10>,
#     <__main__.Channel at 0x1243addd0>,
#     <__main__.Channel at 0x1243ad350>,
#     <__main__.Channel at 0x1243ad610>,
#     <__main__.Channel at 0x1243ad6d0>,
#     <__main__.Channel at 0x1243ad790>,
#     <__main__.Channel at 0x1243add90>,
#     <__main__.Channel at 0x1243afad0>],
#    'inputs': [<__main__.Port at 0x1243a9a10>, <__main__.Port at 0x1243a9b50>],
#    'output': <__main__.Port at 0x1243ad8d0>}})

# %%
csdfs

# %%
csdfs = []

parmethods = [parallel_reduce, recursive_map, recursive_reduce]
recmethods = [recursive_map, recursive_reduce]

sv = [5]
for sv in [10, 15, 20, 30, 50, 75, 100, 150, 200, 250, 300, 350, 400, 450, 500]:
    for fn in fs:
        csdfs.append((fn, 'par'+str(sv), try_do("highLevel/"+fn, parmethods, [sv] * 10)))
        csdfs.append((fn, 'rec'+str(sv), try_do("highLevel/"+fn, recmethods, [sv] * 10)))

    csdfs = [x for x in csdfs if x[2] != False]
    # printls(csdfs)

    for csdf in csdfs:
        write_csdf(csdf[2]['graph'], 'csdf_xmls2/'+csdf[0]+"_"+csdf[1]+'_.xml')
        smushed = compose_maps(csdf[2]['graph'])
        write_csdf(smushed, 'csdf_xmls2/'+csdf[0]+"_"+csdf[1]+'_cmap_.xml')

# %%
n = p['graph']['nodes']
g = n[1].subfunc
printls(g['inputs'])
print(g['output'])

# %%
printgraph(g)

# %%
set(fs).difference(set(success_rec))

# %%
set(fs).difference(set(success_par))

# %%
success_rec

# %% [markdown]
# okay so:
#
# - managed to compile 18/21, both recursive and parallel
# - of the two that failed, is because the produce an Unknown datatype that ends up cycling back into a Map/Reduce so we don't have length data
# - but hey 85% success rate

# %%
ks = [c for c in csdfs if c[0] == 'mappy'and '4' in c[1]and '0' not in c[1]]
for k in ks:
    print(k[1])
    printgraph_simple(k[2]['graph'])
    print('\n')

# %%
# %run Generators.ipynb
# k = try_do("highLevel/mappy", recmethods, [10] * 10)['graph']
# write_csdf(k, 'csdf_xmls/mappy.xml')
# printgraph_simple(k)

# %%
for i in [3,10,20,50,80,100,150,200,250,300,450,500]:
    for sv in [3,4,5,7, 10,12,15,20,21,25,28, 30,35,40,45,50,55,60,70, 80, 100, 120, 150, 200, 250,300, 350,400, 450, 500]:
        k = try_do("highLevel/userfun", recmethods, [sv] * 10)['graph']
        write_csdf(k, 'tstuf/uf_'+str(sv)+'_'+str(i)+'_rec_.xml', i)
        k = try_do("highLevel/userfun", parmethods, [sv] * 10)['graph']
        write_csdf(k, 'tstuf/uf_'+str(sv)+'_'+str(i)+'_par_.xml', i)

# %%
parmethods = [parallel_map, recursive_reduce]
recmethods = [recursive_map, recursive_reduce]
k = try_do("highLevel/asum", recmethods, [200] * 10)['graph']
write_csdf(k, 'parmapping/aaaamappy_rec_.xml')
k = try_do("highLevel/asum", parmethods, [200] * 10)['graph']
write_csdf(k, 'parmapping/aaaamappy_par_.xml')

# %%
# %run Generators.ipynb

# %%
import timeit


parreducemethods = [parallel_reduce, recursive_map, recursive_reduce]
parmethods = [parallel_reduce, parallel_map, recursive_reduce]
naivemethods = [recursive_map, recursive_reduce]
parmapmethods = [parallel_map, recursive_reduce]
ls = range(1, 502, 50)
naive_ct = []
par_ct = []
for i in ls:
    naive_ct.append(timeit.timeit('try_do("highLevel/asum", naivemethods, [i])', number=100))
    par_ct.append(timeit.timeit('try_do("highLevel/asum", parmapmethods, [i])', number=100))

# %%
mypath = 'highlevel/'
fs = [f for f in listdir(mypath) if isfile(join(mypath, f)) and not f.endswith('json')]
fs = [x for x in fs if 'mm' not in x] + ['mmNT']

# %%
parreducemethods = [parallel_reduce, recursive_map, recursive_reduce]
parmethods = [parallel_reduce, parallel_map, recursive_reduce]
naivemethods = [recursive_map, recursive_reduce]
parmapmethods = [parallel_map, recursive_reduce]

# %%
fs = ['mmNT']


names = []
csdfs = []

# %%
def generate_and_write(svs, fs):
    csdfs = []

    print("Generating")
    # make csdfs using parallel/not parallel map/reduce methods
    for sv in tqdm(svs):
        for fn in tqdm(fs):
            csdfs.append((fn, 'par'+str(sv), try_do("highLevel/"+fn, parmethods, [sv] * 10)))
            csdfs.append((fn, 'naive'+str(sv), try_do("highLevel/"+fn, naivemethods, [sv] * 10)))
            csdfs.append((fn, 'parreduce'+str(sv), try_do("highLevel/"+fn, parreducemethods, [sv] * 10)))
            csdfs.append((fn, 'parmap'+str(sv), try_do("highLevel/"+fn, parmapmethods, [sv] * 10)))   
    # delete ones where it didn't work
    csdfs = [x for x in csdfs if x[2] != False]         
    print('Generation Complete')

    # Transform by making zip 
    print("Discrete Zip")
    extras = []
    for x in tqdm(csdfs):
        if 'dz' not in x[1]:
            g = x[2]['graph']
            nodes = [getcn(n) for n in g['nodes']]
            if 'Zip' in nodes:
                csdf_copy = copy.deepcopy(g)
                discrete_zip(csdf_copy, None)
                extras.append((x[0],  x[1]+"_dz", csdf_copy))
    csdfs += extras
    csdfs = [(a[0], a[1], b) for a, b in dict([((x[0], x[1]), x[2]) for x in csdfs]).items()]
    print('Discrete Zip complete')


    # Write to file
    print("Writing to files")
    for csdf in tqdm(csdfs):
        nbase =  'curr/'+csdf[0]+"_"+csdf[1]
        n1 =nbase+'_.xml'
        n2 = nbase+'_cmap_.xml'
        write_csdf(csdf[2]['graph'], n1)
        smushed = compose_maps(csdf[2]['graph'])
        write_csdf(smushed, n2)

    print('Finished')
