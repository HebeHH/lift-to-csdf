# %%
# %run Generators.ipynb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/Documents/Uni/Capstone/lift-to-csdf/Generators.ipynb in <module>
# ----> 1 write_csdf_from_hl(add_cwd('highLevel/mmNN'), add_cwd('csdf_xmls/mmNN'))
#
# ~/Documents/Uni/Capstone/lift-to-csdf/Generators.ipynb in write_csdf_from_hl(from_file, to_file)
#      13
#      14 def write_csdf_from_hl(from_file, to_file):
# ---> 15     write_csdf(get_rec_csdf(from_file), to_file)
#      16
#
# ~/Documents/Uni/Capstone/lift-to-csdf/Generators.ipynb in get_rec_csdf(filename)
#       5     g = p['graph']
#       6     rec_explode(g)
# ----> 7     cascade(p, lambda x: leng)
#       8     add_dt_to_channels(p)
#       9     smush_rede(g)
#
# ~/Documents/Uni/Capstone/lift-to-csdf/Generators.ipynb in cascade(program, sv_maker)
#      19     nd = dict([(n.name, n) for n in ns])
#      20     cbsp = dict([(c.src_port, c) for c in cs])
# ...

# %%
write_csdf_from_hl(add_cwd('highLevel/mmNN'), add_cwd('csdf_xmls/mmNN.xml'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d9466ad87728> in <module>
# ----> 1 write_csdf_from_hl(add_cwd('highLevel/mmNN'), add_cwd('csdf_xmls/mmNN.xml'))
#
# <ipython-input-3-f0d788f0d81b> in write_csdf_from_hl(from_file, to_file)
#      13
#      14 def write_csdf_from_hl(from_file, to_file):
# ---> 15     write_csdf(get_rec_csdf(from_file), to_file)
#      16
#
# <ipython-input-3-f0d788f0d81b> in get_rec_csdf(filename)
#       5     g = p['graph']
#       6     rec_explode(g)
# ----> 7     cascade(p, lambda x: leng)
#       8     add_dt_to_channels(p)
#       9     smush_rede(g)
#
# <ipython-input-3-3e8b86e161c3> in cascade(program, sv_maker)
#      19     nd = dict([(n.name, n) for n in ns])
#      20     cbsp = dict([(c.src_port, c) for c in cs])
# ...
